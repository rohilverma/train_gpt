# %%
# !pip install transformers
# !pip install datasets
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.27.1-py3-none-any.whl (6.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.7/6.7 MB 83.7 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from transformers) (6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from transformers) (3.10.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.9/dist-packages (from transformers) (2022.10.31)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 100.6 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.9/dist-packages (from transformers) (4.65.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.9/dist-packages (from transformers) (1.22.4)
# Collecting huggingface-hub<1.0,>=0.11.0
#   Downloading huggingface_hub-0.13.2-py3-none-any.whl (199 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.2/199.2 KB 23.1 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from transformers) (2.27.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from transformers) (23.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (4.5.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (1.26.15)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (2022.12.7)
# Installing collected packages: tokenizers, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.13.2 tokenizers-0.13.2 transformers-4.27.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting datasets
#   Downloading datasets-2.10.1-py3-none-any.whl (469 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 469.0/469.0 KB 18.3 MB/s eta 0:00:00
# Collecting aiohttp
#   Downloading aiohttp-3.8.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 62.4 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from datasets) (23.0)
# Collecting multiprocess
#   Downloading multiprocess-0.70.14-py39-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.9/132.9 KB 17.6 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.9/dist-packages (from datasets) (2023.3.0)
# Requirement already satisfied: pyarrow>=6.0.0 in /usr/local/lib/python3.9/dist-packages (from datasets) (9.0.0)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.9/dist-packages (from datasets) (2.27.1)
# Collecting responses<0.19
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Collecting xxhash
#   Downloading xxhash-3.2.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (212 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.2/212.2 KB 7.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.9/dist-packages (from datasets) (1.22.4)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.9/dist-packages (from datasets) (4.65.0)
# Collecting dill<0.3.7,>=0.3.0
#   Downloading dill-0.3.6-py3-none-any.whl (110 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 KB 14.9 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (from datasets) (1.4.4)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from datasets) (6.0)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.2.0 in /usr/local/lib/python3.9/dist-packages (from datasets) (0.13.2)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets) (2.0.12)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.3-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (158 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.8/158.8 KB 17.5 MB/s eta 0:00:00
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.2/114.2 KB 14.4 MB/s eta 0:00:00
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets) (22.2.0)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.8.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (264 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 264.6/264.6 KB 22.4 MB/s eta 0:00:00
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from huggingface-hub<1.0.0,>=0.2.0->datasets) (3.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub<1.0.0,>=0.2.0->datasets) (4.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests>=2.19.0->datasets) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests>=2.19.0->datasets) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests>=2.19.0->datasets) (1.26.15)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas->datasets) (2022.7.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.15.0)
# Installing collected packages: xxhash, multidict, frozenlist, dill, async-timeout, yarl, responses, multiprocess, aiosignal, aiohttp, datasets
# Successfully installed aiohttp-3.8.4 aiosignal-1.3.1 async-timeout-4.0.2 datasets-2.10.1 dill-0.3.6 frozenlist-1.3.3 multidict-6.0.4 multiprocess-0.70.14 responses-0.18.0 xxhash-3.2.0 yarl-1.8.2

# %%
from transformers import GPT2Tokenizer, GPT2LMHeadModel
import torch as t

tokenizer = GPT2Tokenizer.from_pretrained("gpt2")
pretrained_model = GPT2LMHeadModel.from_pretrained("gpt2")
# Out:
# Downloading (…)olve/main/vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# Downloading (…)olve/main/merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/548M [00:00<?, ?B/s]
# Downloading (…)neration_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]

# %%
pretrained_model
# Out:
# GPT2LMHeadModel(
#   (transformer): GPT2Model(
#     (wte): Embedding(50257, 768)
#     (wpe): Embedding(1024, 768)
#     (drop): Dropout(p=0.1, inplace=False)
#     (h): ModuleList(
#       (0): GPT2Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): GPT2Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): GPT2MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (act): NewGELUActivation()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (1): GPT2Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): GPT2Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): GPT2MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (act): NewGELUActivation()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (2): GPT2Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): GPT2Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): GPT2MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (act): NewGELUActivation()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (3): GPT2Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): GPT2Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): GPT2MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (act): NewGELUActivation()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (4): GPT2Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): GPT2Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): GPT2MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (act): NewGELUActivation()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (5): GPT2Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): GPT2Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): GPT2MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (act): NewGELUActivation()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (6): GPT2Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): GPT2Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): GPT2MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (act): NewGELUActivation()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (7): GPT2Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): GPT2Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): GPT2MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (act): NewGELUActivation()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (8): GPT2Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): GPT2Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): GPT2MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (act): NewGELUActivation()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (9): GPT2Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): GPT2Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): GPT2MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (act): NewGELUActivation()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (10): GPT2Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): GPT2Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): GPT2MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (act): NewGELUActivation()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (11): GPT2Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): GPT2Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): GPT2MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (act): NewGELUActivation()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#     )
#     (ln_f): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#   )
#   (lm_head): Linear(in_features=768, out_features=50257, bias=False)
# )

# %%
from datasets import load_dataset
ds = load_dataset('stas/openwebtext-10k')
# Out:
# Downloading builder script:   0%|          | 0.00/3.08k [00:00<?, ?B/s]
# Downloading metadata:   0%|          | 0.00/1.33k [00:00<?, ?B/s]
# Downloading readme:   0%|          | 0.00/951 [00:00<?, ?B/s]
# Downloading and preparing dataset openwebtext-10k/plain_text (download: 14.04 MiB, generated: 47.37 MiB, post-processed: Unknown size, total: 61.41 MiB) to /root/.cache/huggingface/datasets/stas___openwebtext-10k/plain_text/1.0.0/3a8df094c671b4cb63ed0b41f40fb3bd855e9ce2e3765e5df50abcdfb5ec144b...
# Downloading data:   0%|          | 0.00/14.7M [00:00<?, ?B/s]
# /usr/local/lib/python3.9/dist-packages/datasets/download/download_manager.py:527: FutureWarning: 'num_proc' was deprecated in version 2.6.2 and will be removed in 3.0.0. Pass `DownloadConfig(num_proc=<num_proc>)` to the initializer instead.
#   warnings.warn(
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Generating train split:   0%|          | 0/10000 [00:00<?, ? examples/s]
# Dataset openwebtext-10k downloaded and prepared to /root/.cache/huggingface/datasets/stas___openwebtext-10k/plain_text/1.0.0/3a8df094c671b4cb63ed0b41f40fb3bd855e9ce2e3765e5df50abcdfb5ec144b. Subsequent calls will reuse this data.
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
tokenizer.pad_token = tokenizer.eos_token
dataset = ds['train']['text']

# %%
def init_layer(layer: t.nn.Module):
    if isinstance(layer, t.nn.Embedding) or isinstance(layer, t.nn.Linear):
        layer.weight.data.normal_(0, 0.02)

# %%
class GPTBlock(t.nn.Module):
    def __init__(self, hidden_size = 768, context_length = 1024, dim_size = 3072, p_dropout = 0.1, n_heads = 12):
        super().__init__()
        self.ln_init = t.nn.LayerNorm(hidden_size)
        self.attn = t.nn.MultiheadAttention(hidden_size, n_heads, p_dropout, batch_first = True)
        mask = (t.triu(t.ones(context_length, context_length)) == 1).transpose(0, 1)
        mask = mask.float().masked_fill(mask == 0, float('-inf')).masked_fill(mask == 1, float(0.0))
        self.attn_mask = t.nn.Parameter(mask, requires_grad = False)
        self.ln_intermediate = t.nn.LayerNorm(hidden_size)
        self.nn1 = t.nn.Linear(hidden_size, dim_size)
        self.nn2 = t.nn.Linear(dim_size, hidden_size)
        self.gelu = t.nn.GELU()
        self.dropout = t.nn.Dropout(p_dropout)
    
    def forward(self, x):
        x = self.ln_init(x)
        x, _ = self.attn(x, x, x, attn_mask = self.attn_mask, need_weights = False)
        x = self.ln_intermediate(x)
        x = self.nn1(x)
        x = self.nn2(x)
        x = self.gelu(x)
        return self.dropout(x)

# %%
class SimpleGPT2(t.nn.Module):
    def __init__(self, n_blocks = 1, vocab_size = 50257, context_length = 1024, hidden_size = 768, p_dropout = 0.1):
        super().__init__()
        self.wte = t.nn.Embedding(vocab_size, hidden_size)
        self.wpe = t.nn.Embedding(context_length, hidden_size)
        self.pe_matrix = t.nn.Parameter(t.arange(0, context_length).unsqueeze(0), requires_grad = False)
        self.dropout = t.nn.Dropout(p_dropout)
        self.gpt_blocks = t.nn.ModuleList([GPTBlock() for _ in range(n_blocks)])
        self.layernorm = t.nn.LayerNorm(hidden_size)
        self.final = t.nn.Linear(hidden_size, vocab_size)

        for layer in [self.wte, self.wpe, self.final]:
            init_layer(layer)
    
    def forward(self, input_ids: t.Tensor, attention_mask = t.Tensor):
      x = input_ids
      n, seq_len = x.shape
      hidden = self.wte(x) + self.wpe(self.pe_matrix.expand(n, -1))
      hidden = self.dropout(hidden)
      for gpt_block in self.gpt_blocks:
          hidden = gpt_block(hidden)
      hidden = self.layernorm(hidden)
      return self.final(hidden)

# %%
simpleGPT2 = SimpleGPT2()
device = t.device("cuda:0" if t.cuda.is_available() else "cpu")
simpleGPT2.to(device)

# Run model on a few truncated samples ... works!

encoded_input = tokenizer(dataset[0:1], return_tensors='pt', padding='max_length', truncation=True).to(device)
print(encoded_input['attention_mask'].shape, encoded_input['attention_mask'].sum())
logits = simpleGPT2(**encoded_input)
print(logits.shape)
# Out:
# torch.Size([1, 1024]) tensor(1024, device='cuda:0')
# torch.Size([1, 1024, 50257])

# %%
# How many parameters?
print(sum((p.numel() if p.requires_grad else 0 for p in simpleGPT2.parameters())))
# Out:
# 85120849

# %%
encoded_input_alt = tokenizer(dataset[0][:100], return_tensors='pt', padding='max_length', truncation=True).to(device)
print(encoded_input_alt['attention_mask'].shape, encoded_input_alt['attention_mask'].sum())
# Out:
# torch.Size([1, 1024]) tensor(21, device='cuda:0')

# %%
def greedy_sampling(logits):
  return logits.argmax()

def test_model(model, text = "Replace me by any text you'd like.", steps = 100, sampling = greedy_sampling):
    eos_token = "<|endoftext|>"
    prompt = text
    print("Starting prompt: " + prompt)

    for i in range(steps):
        encoded_input = tokenizer([prompt], return_tensors="pt", padding='max_length').to(device)
        logits = model(**encoded_input)[0, -1]
        next_token = sampling(logits)
        next_string = tokenizer.decode(next_token)
        if next_string == eos_token:
            break
        prompt = prompt + next_string
    print("Current generation: " + prompt)

# %%
def top_k_sampling(k):


      def top_sampling(logits):
          probs = t.nn.functional.softmax(logits)
          values, indices = t.topk(probs, k)
          index = values.multinomial(num_samples = 1, replacement = True)
          return indices[index]
      
      return top_sampling

# Initial model generates nonsense
test_model(simpleGPT2, text = "Mary is the greatest. Or is she?", steps = 100, sampling = top_k_sampling(10))
# Out:
# Starting prompt: Mary is the greatest. Or is she?
# <ipython-input-78-65651643be1d>:5: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   probs = t.nn.functional.softmax(logits)
# <ipython-input-78-65651643be1d>:5: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   probs = t.nn.functional.softmax(logits)
# Current generation: Mary is the greatest. Or is she?withstanding Shelter Mattis corrupt Pop mattress Arctic PART Mattis inco ArcticLevelHAics ArcticFram crowcarbwatchcarb Shelter Arctic obligationsorersics Marilyn Benz PART Mattis PART Viper Arctic Shelter exposition wellbeingLevel Shelterwithstanding PARTcarbcarb Shelter grandsonTal ShelterTal imperative blinking illusionsorershemat014 Shelter scratching exposition illusions Movements Saddam Pop Mattis mattress PART Saddamappiness Saddam Saddamhammer assurance exposition corrupt MattisggingFORcarb exposition exposition Shelter corruptTal Shelter Pop imperativeMM Mattis Saddamcarb expositioncarb Shelterursed Saddam minded filing altogether Shelter Shelter Mattis Arctic Pop

# %%
def loss_fn(logits, encoded_input):
    # logits: n x seq x d
    # true_tokens: n x seq
    # attention_mask = n x seq
    true_tokens = encoded_input['input_ids']
    attention_mask = encoded_input['attention_mask']
    valid_samples_mask = attention_mask[:, 1:].reshape(-1).bool()
    n, seq, d  = logits.shape
    return t.nn.functional.cross_entropy(logits[:, :-1, :].reshape(-1, d)[valid_samples_mask, :], true_tokens[:, 1:].flatten()[valid_samples_mask]), valid_samples_mask.sum()

def compute_dataset_loss(dataset, model, tokenizer):
    loss = 0
    samples = 0
    with t.no_grad():
      n = len(dataset)
      batch_size = 10
      batches = n // batch_size
      for i in range(batches):
          print(i, batch_size, loss, samples)
          batch = dataset[i:i+batch_size]
          encoded_input = tokenizer(batch, return_tensors='pt', padding='max_length', truncation=True).to(device)
          logits = model(**encoded_input)
          # Find true labels and compute loss
          ce_loss, valid_samples = loss_fn(logits, encoded_input)
          loss = (loss * samples + ce_loss * valid_samples ) / (samples + valid_samples)
          samples = samples + valid_samples
    return loss, samples

# Compute loss of the pre-trained model on the truncated dataset
print(compute_dataset_loss(dataset[:100], simpleGPT2, tokenizer))

# Initial loss is ~11, remarkably high
# Out:
# 0 10 0 0
# 1 10 tensor(11.0008, device='cuda:0') tensor(6508, device='cuda:0')
# 2 10 tensor(11.0007, device='cuda:0') tensor(12338, device='cuda:0')
# 3 10 tensor(11.0038, device='cuda:0') tensor(18466, device='cuda:0')
# 4 10 tensor(11.0068, device='cuda:0') tensor(24853, device='cuda:0')
# 5 10 tensor(11.0079, device='cuda:0') tensor(30959, device='cuda:0')
# 6 10 tensor(11.0083, device='cuda:0') tensor(37244, device='cuda:0')
# 7 10 tensor(11.0077, device='cuda:0') tensor(43529, device='cuda:0')
# 8 10 tensor(11.0067, device='cuda:0') tensor(50599, device='cuda:0')
# 9 10 tensor(11.0059, device='cuda:0') tensor(57171, device='cuda:0')
# (tensor(11.0061, device='cuda:0'), tensor(63899, device='cuda:0'))

# %%
def compute_val_dataset_loss(dataset, model, tokenizer, val_frac = 0.2):
    n = len(dataset)
    val_size = int(n * val_frac)
    return compute_dataset_loss(dataset[-val_size:], model, tokenizer)
  
# Compute validation loss
# print(compute_val_dataset_loss(dataset, 0.1))

# %%
# Fine-tune the model on a subset of training set, and then evaluate on val set

def train_model(dataset, optimizer, epochs, model, tokenizer):
    loss = 0
    samples = 0
    n = len(dataset)
    batch_size = 2
    batches = n // batch_size

    scheduler = OneCycleLR(optimizer, max_lr = 2.5e-4, total_steps = epochs * batches, pct_start = 0.2)

    for epoch in range(epochs):
        print("Starting epoch: ", epoch)
        for i in range(batches):
            print(i, batch_size, loss, samples)

            optimizer.zero_grad()

            batch = dataset[i:i+batch_size]
            encoded_input = tokenizer(batch, return_tensors='pt', padding='max_length', truncation=True).to(device)
            logits = model(**encoded_input)

            # Find true labels and compute loss
            ce_loss, valid_samples = loss_fn(logits, encoded_input)
            loss = (loss * samples + ce_loss * valid_samples ) / (samples + valid_samples)
            samples = samples + valid_samples

            # Backprop
            ce_loss.backward()
            optimizer.step()
            scheduler.step()

    return loss, samples

epochs = 1
from torch.optim import Adam
from torch.optim.lr_scheduler import OneCycleLR

lrs = [5e-5, 5e-4, 1e-5, 2e-5]

optimizer = Adam(simpleGPT2.parameters(), lr = lrs[-1])
print(train_model(dataset[:8000], optimizer, epochs, simpleGPT2, tokenizer))
# Loss reaches 5.7 after 3 epochs
# Out:
# Starting epoch:  0
# 0 2 0 0
# 1 2 tensor(5.6635, device='cuda:0', grad_fn=<DivBackward0>) tensor(1748, device='cuda:0')
# 2 2 tensor(5.8169, device='cuda:0', grad_fn=<DivBackward0>) tensor(3237, device='cuda:0')
# 3 2 tensor(5.8600, device='cuda:0', grad_fn=<DivBackward0>) tensor(4870, device='cuda:0')
# 4 2 tensor(5.8320, device='cuda:0', grad_fn=<DivBackward0>) tensor(6057, device='cuda:0')
# 5 2 tensor(5.8420, device='cuda:0', grad_fn=<DivBackward0>) tensor(7398, device='cuda:0')
# 6 2 tensor(5.8705, device='cuda:0', grad_fn=<DivBackward0>) tensor(8659, device='cuda:0')
# 7 2 tensor(5.8746, device='cuda:0', grad_fn=<DivBackward0>) tensor(9700, device='cuda:0')
# 8 2 tensor(5.8525, device='cuda:0', grad_fn=<DivBackward0>) tensor(10865, device='cuda:0')
# 9 2 tensor(5.8402, device='cuda:0', grad_fn=<DivBackward0>) tensor(11610, device='cuda:0')
# 10 2 tensor(5.8464, device='cuda:0', grad_fn=<DivBackward0>) tensor(12338, device='cuda:0')
# 11 2 tensor(5.8313, device='cuda:0', grad_fn=<DivBackward0>) tensor(13706, device='cuda:0')
# 12 2 tensor(5.7970, device='cuda:0', grad_fn=<DivBackward0>) tensor(15752, device='cuda:0')
# 13 2 tensor(5.7978, device='cuda:0', grad_fn=<DivBackward0>) tensor(17363, device='cuda:0')
# 14 2 tensor(5.7976, device='cuda:0', grad_fn=<DivBackward0>) tensor(18448, device='cuda:0')
# 15 2 tensor(5.7663, device='cuda:0', grad_fn=<DivBackward0>) tensor(19968, device='cuda:0')
# 16 2 tensor(5.7503, device='cuda:0', grad_fn=<DivBackward0>) tensor(22014, device='cuda:0')
# 17 2 tensor(5.7639, device='cuda:0', grad_fn=<DivBackward0>) tensor(23342, device='cuda:0')
# 18 2 tensor(5.7657, device='cuda:0', grad_fn=<DivBackward0>) tensor(24165, device='cuda:0')
# 19 2 tensor(5.7431, device='cuda:0', grad_fn=<DivBackward0>) tensor(25332, device='cuda:0')
# 20 2 tensor(5.7532, device='cuda:0', grad_fn=<DivBackward0>) tensor(26984, device='cuda:0')
# 21 2 tensor(5.7714, device='cuda:0', grad_fn=<DivBackward0>) tensor(28327, device='cuda:0')
# 22 2 tensor(5.7803, device='cuda:0', grad_fn=<DivBackward0>) tensor(29690, device='cuda:0')
# 23 2 tensor(5.7942, device='cuda:0', grad_fn=<DivBackward0>) tensor(31655, device='cuda:0')
# 24 2 tensor(5.8265, device='cuda:0', grad_fn=<DivBackward0>) tensor(33620, device='cuda:0')
# 25 2 tensor(5.8595, device='cuda:0', grad_fn=<DivBackward0>) tensor(35471, device='cuda:0')
# 26 2 tensor(5.8635, device='cuda:0', grad_fn=<DivBackward0>) tensor(36546, device='cuda:0')
# 27 2 tensor(5.8610, device='cuda:0', grad_fn=<DivBackward0>) tensor(37213, device='cuda:0')
# 28 2 tensor(5.8575, device='cuda:0', grad_fn=<DivBackward0>) tensor(38330, device='cuda:0')
# 29 2 tensor(5.8505, device='cuda:0', grad_fn=<DivBackward0>) tensor(39445, device='cuda:0')
# 30 2 tensor(5.8601, device='cuda:0', grad_fn=<DivBackward0>) tensor(40339, device='cuda:0')
# 31 2 tensor(5.8821, device='cuda:0', grad_fn=<DivBackward0>) tensor(41517, device='cuda:0')
# 32 2 tensor(5.8841, device='cuda:0', grad_fn=<DivBackward0>) tensor(42902, device='cuda:0')
# 33 2 tensor(5.8820, device='cuda:0', grad_fn=<DivBackward0>) tensor(43899, device='cuda:0')
# 34 2 tensor(5.8980, device='cuda:0', grad_fn=<DivBackward0>) tensor(45236, device='cuda:0')
# 35 2 tensor(5.8929, device='cuda:0', grad_fn=<DivBackward0>) tensor(47282, device='cuda:0')
# 36 2 tensor(5.8785, device='cuda:0', grad_fn=<DivBackward0>) tensor(48672, device='cuda:0')
# 37 2 tensor(5.8693, device='cuda:0', grad_fn=<DivBackward0>) tensor(49651, device='cuda:0')
# 38 2 tensor(5.8786, device='cuda:0', grad_fn=<DivBackward0>) tensor(51286, device='cuda:0')
# 39 2 tensor(5.8978, device='cuda:0', grad_fn=<DivBackward0>) tensor(52619, device='cuda:0')
# 40 2 tensor(5.9062, device='cuda:0', grad_fn=<DivBackward0>) tensor(53952, device='cuda:0')
# 41 2 tensor(5.9251, device='cuda:0', grad_fn=<DivBackward0>) tensor(55715, device='cuda:0')
# 42 2 tensor(5.9324, device='cuda:0', grad_fn=<DivBackward0>) tensor(57478, device='cuda:0')
# 43 2 tensor(5.9254, device='cuda:0', grad_fn=<DivBackward0>) tensor(59524, device='cuda:0')
# 44 2 tensor(5.9230, device='cuda:0', grad_fn=<DivBackward0>) tensor(60729, device='cuda:0')
# 45 2 tensor(5.9166, device='cuda:0', grad_fn=<DivBackward0>) tensor(61934, device='cuda:0')
# 46 2 tensor(5.9048, device='cuda:0', grad_fn=<DivBackward0>) tensor(63903, device='cuda:0')
# 47 2 tensor(5.8956, device='cuda:0', grad_fn=<DivBackward0>) tensor(65589, device='cuda:0')
# 48 2 tensor(5.8927, device='cuda:0', grad_fn=<DivBackward0>) tensor(66538, device='cuda:0')
# 49 2 tensor(5.8916, device='cuda:0', grad_fn=<DivBackward0>) tensor(67509, device='cuda:0')
# 50 2 tensor(5.8860, device='cuda:0', grad_fn=<DivBackward0>) tensor(69294, device='cuda:0')
# 51 2 tensor(5.8836, device='cuda:0', grad_fn=<DivBackward0>) tensor(71340, device='cuda:0')
# 52 2 tensor(5.8795, device='cuda:0', grad_fn=<DivBackward0>) tensor(73386, device='cuda:0')
# 53 2 tensor(5.8771, device='cuda:0', grad_fn=<DivBackward0>) tensor(75041, device='cuda:0')
# 54 2 tensor(5.8796, device='cuda:0', grad_fn=<DivBackward0>) tensor(76696, device='cuda:0')
# 55 2 tensor(5.8789, device='cuda:0', grad_fn=<DivBackward0>) tensor(78305, device='cuda:0')
# 56 2 tensor(5.8698, device='cuda:0', grad_fn=<DivBackward0>) tensor(79914, device='cuda:0')
# 57 2 tensor(5.8608, device='cuda:0', grad_fn=<DivBackward0>) tensor(81146, device='cuda:0')
# 58 2 tensor(5.8672, device='cuda:0', grad_fn=<DivBackward0>) tensor(82378, device='cuda:0')
# 59 2 tensor(5.8732, device='cuda:0', grad_fn=<DivBackward0>) tensor(83812, device='cuda:0')
# 60 2 tensor(5.8706, device='cuda:0', grad_fn=<DivBackward0>) tensor(84974, device='cuda:0')
# 61 2 tensor(5.8683, device='cuda:0', grad_fn=<DivBackward0>) tensor(86482, device='cuda:0')
# 62 2 tensor(5.8690, device='cuda:0', grad_fn=<DivBackward0>) tensor(87647, device='cuda:0')
# 63 2 tensor(5.8793, device='cuda:0', grad_fn=<DivBackward0>) tensor(89044, device='cuda:0')
# 64 2 tensor(5.8971, device='cuda:0', grad_fn=<DivBackward0>) tensor(91056, device='cuda:0')
# 65 2 tensor(5.9044, device='cuda:0', grad_fn=<DivBackward0>) tensor(92402, device='cuda:0')
# 66 2 tensor(5.9044, device='cuda:0', grad_fn=<DivBackward0>) tensor(93021, device='cuda:0')
# 67 2 tensor(5.9062, device='cuda:0', grad_fn=<DivBackward0>) tensor(93653, device='cuda:0')
# 68 2 tensor(5.9071, device='cuda:0', grad_fn=<DivBackward0>) tensor(94313, device='cuda:0')
# 69 2 tensor(5.9089, device='cuda:0', grad_fn=<DivBackward0>) tensor(95379, device='cuda:0')
# 70 2 tensor(5.9107, device='cuda:0', grad_fn=<DivBackward0>) tensor(96863, device='cuda:0')
# 71 2 tensor(5.9095, device='cuda:0', grad_fn=<DivBackward0>) tensor(98044, device='cuda:0')
# 72 2 tensor(5.9092, device='cuda:0', grad_fn=<DivBackward0>) tensor(99506, device='cuda:0')
# 73 2 tensor(5.9050, device='cuda:0', grad_fn=<DivBackward0>) tensor(101552, device='cuda:0')
# 74 2 tensor(5.9007, device='cuda:0', grad_fn=<DivBackward0>) tensor(103023, device='cuda:0')
# 75 2 tensor(5.9045, device='cuda:0', grad_fn=<DivBackward0>) tensor(104494, device='cuda:0')
# 76 2 tensor(5.9110, device='cuda:0', grad_fn=<DivBackward0>) tensor(106540, device='cuda:0')
# 77 2 tensor(5.9130, device='cuda:0', grad_fn=<DivBackward0>) tensor(108069, device='cuda:0')
# 78 2 tensor(5.9147, device='cuda:0', grad_fn=<DivBackward0>) tensor(109598, device='cuda:0')
# 79 2 tensor(5.9172, device='cuda:0', grad_fn=<DivBackward0>) tensor(111644, device='cuda:0')
# 80 2 tensor(5.9179, device='cuda:0', grad_fn=<DivBackward0>) tensor(113429, device='cuda:0')
# 81 2 tensor(5.9193, device='cuda:0', grad_fn=<DivBackward0>) tensor(114397, device='cuda:0')
# 82 2 tensor(5.9271, device='cuda:0', grad_fn=<DivBackward0>) tensor(115626, device='cuda:0')
# 83 2 tensor(5.9345, device='cuda:0', grad_fn=<DivBackward0>) tensor(116822, device='cuda:0')
# 84 2 tensor(5.9348, device='cuda:0', grad_fn=<DivBackward0>) tensor(117317, device='cuda:0')
# 85 2 tensor(5.9370, device='cuda:0', grad_fn=<DivBackward0>) tensor(118662, device='cuda:0')
# 86 2 tensor(5.9395, device='cuda:0', grad_fn=<DivBackward0>) tensor(119980, device='cuda:0')
# 87 2 tensor(5.9403, device='cuda:0', grad_fn=<DivBackward0>) tensor(120445, device='cuda:0')
# 88 2 tensor(5.9408, device='cuda:0', grad_fn=<DivBackward0>) tensor(120904, device='cuda:0')
# 89 2 tensor(5.9402, device='cuda:0', grad_fn=<DivBackward0>) tensor(121409, device='cuda:0')
# 90 2 tensor(5.9378, device='cuda:0', grad_fn=<DivBackward0>) tensor(122648, device='cuda:0')
# 91 2 tensor(5.9376, device='cuda:0', grad_fn=<DivBackward0>) tensor(124443, device='cuda:0')
# 92 2 tensor(5.9413, device='cuda:0', grad_fn=<DivBackward0>) tensor(125998, device='cuda:0')
# 93 2 tensor(5.9447, device='cuda:0', grad_fn=<DivBackward0>) tensor(126977, device='cuda:0')
# 94 2 tensor(5.9446, device='cuda:0', grad_fn=<DivBackward0>) tensor(127709, device='cuda:0')
# 95 2 tensor(5.9421, device='cuda:0', grad_fn=<DivBackward0>) tensor(129079, device='cuda:0')
# 96 2 tensor(5.9415, device='cuda:0', grad_fn=<DivBackward0>) tensor(130089, device='cuda:0')
# 97 2 tensor(5.9426, device='cuda:0', grad_fn=<DivBackward0>) tensor(131146, device='cuda:0')
# 98 2 tensor(5.9405, device='cuda:0', grad_fn=<DivBackward0>) tensor(133050, device='cuda:0')
# 99 2 tensor(5.9368, device='cuda:0', grad_fn=<DivBackward0>) tensor(134466, device='cuda:0')
# 100 2 tensor(5.9361, device='cuda:0', grad_fn=<DivBackward0>) tensor(135882, device='cuda:0')
# 101 2 tensor(5.9355, device='cuda:0', grad_fn=<DivBackward0>) tensor(137417, device='cuda:0')
# 102 2 tensor(5.9311, device='cuda:0', grad_fn=<DivBackward0>) tensor(138952, device='cuda:0')
# 103 2 tensor(5.9346, device='cuda:0', grad_fn=<DivBackward0>) tensor(140998, device='cuda:0')
# 104 2 tensor(5.9419, device='cuda:0', grad_fn=<DivBackward0>) tensor(143044, device='cuda:0')
# 105 2 tensor(5.9394, device='cuda:0', grad_fn=<DivBackward0>) tensor(144743, device='cuda:0')
# 106 2 tensor(5.9384, device='cuda:0', grad_fn=<DivBackward0>) tensor(146265, device='cuda:0')
# 107 2 tensor(5.9402, device='cuda:0', grad_fn=<DivBackward0>) tensor(148134, device='cuda:0')
# 108 2 tensor(5.9389, device='cuda:0', grad_fn=<DivBackward0>) tensor(150074, device='cuda:0')
# 109 2 tensor(5.9398, device='cuda:0', grad_fn=<DivBackward0>) tensor(151431, device='cuda:0')
# 110 2 tensor(5.9426, device='cuda:0', grad_fn=<DivBackward0>) tensor(152894, device='cuda:0')
# 111 2 tensor(5.9454, device='cuda:0', grad_fn=<DivBackward0>) tensor(154737, device='cuda:0')
# 112 2 tensor(5.9506, device='cuda:0', grad_fn=<DivBackward0>) tensor(156340, device='cuda:0')
# 113 2 tensor(5.9572, device='cuda:0', grad_fn=<DivBackward0>) tensor(158146, device='cuda:0')
# 114 2 tensor(5.9580, device='cuda:0', grad_fn=<DivBackward0>) tensor(159700, device='cuda:0')
# 115 2 tensor(5.9557, device='cuda:0', grad_fn=<DivBackward0>) tensor(160977, device='cuda:0')
# 116 2 tensor(5.9562, device='cuda:0', grad_fn=<DivBackward0>) tensor(162141, device='cuda:0')
# 117 2 tensor(5.9512, device='cuda:0', grad_fn=<DivBackward0>) tensor(163582, device='cuda:0')
# 118 2 tensor(5.9472, device='cuda:0', grad_fn=<DivBackward0>) tensor(164868, device='cuda:0')
# 119 2 tensor(5.9459, device='cuda:0', grad_fn=<DivBackward0>) tensor(165926, device='cuda:0')
# 120 2 tensor(5.9433, device='cuda:0', grad_fn=<DivBackward0>) tensor(167498, device='cuda:0')
# 121 2 tensor(5.9450, device='cuda:0', grad_fn=<DivBackward0>) tensor(169298, device='cuda:0')
# 122 2 tensor(5.9525, device='cuda:0', grad_fn=<DivBackward0>) tensor(170798, device='cuda:0')
# 123 2 tensor(5.9560, device='cuda:0', grad_fn=<DivBackward0>) tensor(172298, device='cuda:0')
# 124 2 tensor(5.9505, device='cuda:0', grad_fn=<DivBackward0>) tensor(174344, device='cuda:0')
# 125 2 tensor(5.9467, device='cuda:0', grad_fn=<DivBackward0>) tensor(176149, device='cuda:0')
# 126 2 tensor(5.9478, device='cuda:0', grad_fn=<DivBackward0>) tensor(177416, device='cuda:0')
# 127 2 tensor(5.9476, device='cuda:0', grad_fn=<DivBackward0>) tensor(178536, device='cuda:0')
# 128 2 tensor(5.9465, device='cuda:0', grad_fn=<DivBackward0>) tensor(180194, device='cuda:0')
# 129 2 tensor(5.9456, device='cuda:0', grad_fn=<DivBackward0>) tensor(181976, device='cuda:0')
# 130 2 tensor(5.9424, device='cuda:0', grad_fn=<DivBackward0>) tensor(183484, device='cuda:0')
# 131 2 tensor(5.9390, device='cuda:0', grad_fn=<DivBackward0>) tensor(185256, device='cuda:0')
# 132 2 tensor(5.9383, device='cuda:0', grad_fn=<DivBackward0>) tensor(186674, device='cuda:0')
# 133 2 tensor(5.9390, device='cuda:0', grad_fn=<DivBackward0>) tensor(188092, device='cuda:0')
# 134 2 tensor(5.9403, device='cuda:0', grad_fn=<DivBackward0>) tensor(190138, device='cuda:0')
# 135 2 tensor(5.9417, device='cuda:0', grad_fn=<DivBackward0>) tensor(191862, device='cuda:0')
# 136 2 tensor(5.9379, device='cuda:0', grad_fn=<DivBackward0>) tensor(193561, device='cuda:0')
# 137 2 tensor(5.9349, device='cuda:0', grad_fn=<DivBackward0>) tensor(194915, device='cuda:0')
# 138 2 tensor(5.9363, device='cuda:0', grad_fn=<DivBackward0>) tensor(195494, device='cuda:0')
# 139 2 tensor(5.9350, device='cuda:0', grad_fn=<DivBackward0>) tensor(196363, device='cuda:0')
# 140 2 tensor(5.9343, device='cuda:0', grad_fn=<DivBackward0>) tensor(198032, device='cuda:0')
# 141 2 tensor(5.9340, device='cuda:0', grad_fn=<DivBackward0>) tensor(200078, device='cuda:0')
# 142 2 tensor(5.9309, device='cuda:0', grad_fn=<DivBackward0>) tensor(202124, device='cuda:0')
# 143 2 tensor(5.9286, device='cuda:0', grad_fn=<DivBackward0>) tensor(203942, device='cuda:0')
# 144 2 tensor(5.9285, device='cuda:0', grad_fn=<DivBackward0>) tensor(205413, device='cuda:0')
# 145 2 tensor(5.9281, device='cuda:0', grad_fn=<DivBackward0>) tensor(206499, device='cuda:0')
# 146 2 tensor(5.9260, device='cuda:0', grad_fn=<DivBackward0>) tensor(207932, device='cuda:0')
# 147 2 tensor(5.9212, device='cuda:0', grad_fn=<DivBackward0>) tensor(209978, device='cuda:0')
# 148 2 tensor(5.9202, device='cuda:0', grad_fn=<DivBackward0>) tensor(211560, device='cuda:0')
# 149 2 tensor(5.9309, device='cuda:0', grad_fn=<DivBackward0>) tensor(213142, device='cuda:0')
# 150 2 tensor(5.9398, device='cuda:0', grad_fn=<DivBackward0>) tensor(215155, device='cuda:0')
# 151 2 tensor(5.9400, device='cuda:0', grad_fn=<DivBackward0>) tensor(216334, device='cuda:0')
# 152 2 tensor(5.9398, device='cuda:0', grad_fn=<DivBackward0>) tensor(217546, device='cuda:0')
# 153 2 tensor(5.9476, device='cuda:0', grad_fn=<DivBackward0>) tensor(219592, device='cuda:0')
# 154 2 tensor(5.9567, device='cuda:0', grad_fn=<DivBackward0>) tensor(221410, device='cuda:0')
# 155 2 tensor(5.9572, device='cuda:0', grad_fn=<DivBackward0>) tensor(222555, device='cuda:0')
# 156 2 tensor(5.9560, device='cuda:0', grad_fn=<DivBackward0>) tensor(223431, device='cuda:0')
# 157 2 tensor(5.9537, device='cuda:0', grad_fn=<DivBackward0>) tensor(224980, device='cuda:0')
# 158 2 tensor(5.9519, device='cuda:0', grad_fn=<DivBackward0>) tensor(226309, device='cuda:0')
# 159 2 tensor(5.9533, device='cuda:0', grad_fn=<DivBackward0>) tensor(227638, device='cuda:0')
# 160 2 tensor(5.9547, device='cuda:0', grad_fn=<DivBackward0>) tensor(228847, device='cuda:0')
# 161 2 tensor(5.9545, device='cuda:0', grad_fn=<DivBackward0>) tensor(229365, device='cuda:0')
# 162 2 tensor(5.9540, device='cuda:0', grad_fn=<DivBackward0>) tensor(230013, device='cuda:0')
# 163 2 tensor(5.9541, device='cuda:0', grad_fn=<DivBackward0>) tensor(231352, device='cuda:0')
# 164 2 tensor(5.9537, device='cuda:0', grad_fn=<DivBackward0>) tensor(233122, device='cuda:0')
# 165 2 tensor(5.9532, device='cuda:0', grad_fn=<DivBackward0>) tensor(234797, device='cuda:0')
# 166 2 tensor(5.9532, device='cuda:0', grad_fn=<DivBackward0>) tensor(236017, device='cuda:0')
# 167 2 tensor(5.9592, device='cuda:0', grad_fn=<DivBackward0>) tensor(237332, device='cuda:0')
# 168 2 tensor(5.9636, device='cuda:0', grad_fn=<DivBackward0>) tensor(239331, device='cuda:0')
# 169 2 tensor(5.9624, device='cuda:0', grad_fn=<DivBackward0>) tensor(241330, device='cuda:0')
# 170 2 tensor(5.9634, device='cuda:0', grad_fn=<DivBackward0>) tensor(243376, device='cuda:0')
# 171 2 tensor(5.9655, device='cuda:0', grad_fn=<DivBackward0>) tensor(245422, device='cuda:0')
# 172 2 tensor(5.9664, device='cuda:0', grad_fn=<DivBackward0>) tensor(247413, device='cuda:0')
# 173 2 tensor(5.9687, device='cuda:0', grad_fn=<DivBackward0>) tensor(249404, device='cuda:0')
# 174 2 tensor(5.9709, device='cuda:0', grad_fn=<DivBackward0>) tensor(251450, device='cuda:0')
# 175 2 tensor(5.9714, device='cuda:0', grad_fn=<DivBackward0>) tensor(253137, device='cuda:0')
# 176 2 tensor(5.9724, device='cuda:0', grad_fn=<DivBackward0>) tensor(254520, device='cuda:0')
# 177 2 tensor(5.9732, device='cuda:0', grad_fn=<DivBackward0>) tensor(256262, device='cuda:0')
# 178 2 tensor(5.9739, device='cuda:0', grad_fn=<DivBackward0>) tensor(257855, device='cuda:0')
# 179 2 tensor(5.9717, device='cuda:0', grad_fn=<DivBackward0>) tensor(259448, device='cuda:0')
# 180 2 tensor(5.9700, device='cuda:0', grad_fn=<DivBackward0>) tensor(261020, device='cuda:0')
# 181 2 tensor(5.9703, device='cuda:0', grad_fn=<DivBackward0>) tensor(262003, device='cuda:0')
# 182 2 tensor(5.9704, device='cuda:0', grad_fn=<DivBackward0>) tensor(263460, device='cuda:0')
# 183 2 tensor(5.9742, device='cuda:0', grad_fn=<DivBackward0>) tensor(265506, device='cuda:0')
# 184 2 tensor(5.9811, device='cuda:0', grad_fn=<DivBackward0>) tensor(267552, device='cuda:0')
# 185 2 tensor(5.9834, device='cuda:0', grad_fn=<DivBackward0>) tensor(269598, device='cuda:0')
# 186 2 tensor(5.9814, device='cuda:0', grad_fn=<DivBackward0>) tensor(271343, device='cuda:0')
# 187 2 tensor(5.9826, device='cuda:0', grad_fn=<DivBackward0>) tensor(273088, device='cuda:0')
# 188 2 tensor(5.9830, device='cuda:0', grad_fn=<DivBackward0>) tensor(274779, device='cuda:0')
# 189 2 tensor(5.9799, device='cuda:0', grad_fn=<DivBackward0>) tensor(276175, device='cuda:0')
# 190 2 tensor(5.9763, device='cuda:0', grad_fn=<DivBackward0>) tensor(277926, device='cuda:0')
# 191 2 tensor(5.9737, device='cuda:0', grad_fn=<DivBackward0>) tensor(279269, device='cuda:0')
# 192 2 tensor(5.9731, device='cuda:0', grad_fn=<DivBackward0>) tensor(280099, device='cuda:0')
# 193 2 tensor(5.9719, device='cuda:0', grad_fn=<DivBackward0>) tensor(281632, device='cuda:0')
# 194 2 tensor(5.9717, device='cuda:0', grad_fn=<DivBackward0>) tensor(283678, device='cuda:0')
# 195 2 tensor(5.9714, device='cuda:0', grad_fn=<DivBackward0>) tensor(285724, device='cuda:0')
# 196 2 tensor(5.9721, device='cuda:0', grad_fn=<DivBackward0>) tensor(287358, device='cuda:0')
# 197 2 tensor(5.9737, device='cuda:0', grad_fn=<DivBackward0>) tensor(288514, device='cuda:0')
# 198 2 tensor(5.9734, device='cuda:0', grad_fn=<DivBackward0>) tensor(290082, device='cuda:0')
# 199 2 tensor(5.9727, device='cuda:0', grad_fn=<DivBackward0>) tensor(291775, device='cuda:0')
# 200 2 tensor(5.9739, device='cuda:0', grad_fn=<DivBackward0>) tensor(292788, device='cuda:0')
# 201 2 tensor(5.9754, device='cuda:0', grad_fn=<DivBackward0>) tensor(293350, device='cuda:0')
# 202 2 tensor(5.9739, device='cuda:0', grad_fn=<DivBackward0>) tensor(294254, device='cuda:0')
# 203 2 tensor(5.9724, device='cuda:0', grad_fn=<DivBackward0>) tensor(295418, device='cuda:0')
# 204 2 tensor(5.9721, device='cuda:0', grad_fn=<DivBackward0>) tensor(296105, device='cuda:0')
# 205 2 tensor(5.9723, device='cuda:0', grad_fn=<DivBackward0>) tensor(296896, device='cuda:0')
# 206 2 tensor(5.9722, device='cuda:0', grad_fn=<DivBackward0>) tensor(297726, device='cuda:0')
# 207 2 tensor(5.9721, device='cuda:0', grad_fn=<DivBackward0>) tensor(298240, device='cuda:0')
# 208 2 tensor(5.9723, device='cuda:0', grad_fn=<DivBackward0>) tensor(299530, device='cuda:0')
# 209 2 tensor(5.9732, device='cuda:0', grad_fn=<DivBackward0>) tensor(301345, device='cuda:0')
# 210 2 tensor(5.9737, device='cuda:0', grad_fn=<DivBackward0>) tensor(303160, device='cuda:0')
# 211 2 tensor(5.9742, device='cuda:0', grad_fn=<DivBackward0>) tensor(304497, device='cuda:0')
# 212 2 tensor(5.9748, device='cuda:0', grad_fn=<DivBackward0>) tensor(304988, device='cuda:0')
# 213 2 tensor(5.9734, device='cuda:0', grad_fn=<DivBackward0>) tensor(305634, device='cuda:0')
# 214 2 tensor(5.9731, device='cuda:0', grad_fn=<DivBackward0>) tensor(306510, device='cuda:0')
# 215 2 tensor(5.9740, device='cuda:0', grad_fn=<DivBackward0>) tensor(307672, device='cuda:0')
# 216 2 tensor(5.9735, device='cuda:0', grad_fn=<DivBackward0>) tensor(308757, device='cuda:0')
# 217 2 tensor(5.9731, device='cuda:0', grad_fn=<DivBackward0>) tensor(309606, device='cuda:0')
# 218 2 tensor(5.9729, device='cuda:0', grad_fn=<DivBackward0>) tensor(311148, device='cuda:0')
# 219 2 tensor(5.9706, device='cuda:0', grad_fn=<DivBackward0>) tensor(312600, device='cuda:0')
# 220 2 tensor(5.9675, device='cuda:0', grad_fn=<DivBackward0>) tensor(314052, device='cuda:0')
# 221 2 tensor(5.9660, device='cuda:0', grad_fn=<DivBackward0>) tensor(316098, device='cuda:0')
# 222 2 tensor(5.9648, device='cuda:0', grad_fn=<DivBackward0>) tensor(317573, device='cuda:0')
# 223 2 tensor(5.9647, device='cuda:0', grad_fn=<DivBackward0>) tensor(318333, device='cuda:0')
# 224 2 tensor(5.9652, device='cuda:0', grad_fn=<DivBackward0>) tensor(318884, device='cuda:0')
# 225 2 tensor(5.9627, device='cuda:0', grad_fn=<DivBackward0>) tensor(320150, device='cuda:0')
# 226 2 tensor(5.9608, device='cuda:0', grad_fn=<DivBackward0>) tensor(321500, device='cuda:0')
# 227 2 tensor(5.9605, device='cuda:0', grad_fn=<DivBackward0>) tensor(322773, device='cuda:0')
# 228 2 tensor(5.9599, device='cuda:0', grad_fn=<DivBackward0>) tensor(324071, device='cuda:0')
# 229 2 tensor(5.9607, device='cuda:0', grad_fn=<DivBackward0>) tensor(325446, device='cuda:0')
# 230 2 tensor(5.9642, device='cuda:0', grad_fn=<DivBackward0>) tensor(327492, device='cuda:0')
# 231 2 tensor(5.9671, device='cuda:0', grad_fn=<DivBackward0>) tensor(328891, device='cuda:0')
# 232 2 tensor(5.9667, device='cuda:0', grad_fn=<DivBackward0>) tensor(329713, device='cuda:0')
# 233 2 tensor(5.9659, device='cuda:0', grad_fn=<DivBackward0>) tensor(331182, device='cuda:0')
# 234 2 tensor(5.9657, device='cuda:0', grad_fn=<DivBackward0>) tensor(332565, device='cuda:0')
# 235 2 tensor(5.9649, device='cuda:0', grad_fn=<DivBackward0>) tensor(333948, device='cuda:0')
# 236 2 tensor(5.9642, device='cuda:0', grad_fn=<DivBackward0>) tensor(335994, device='cuda:0')
# 237 2 tensor(5.9631, device='cuda:0', grad_fn=<DivBackward0>) tensor(337861, device='cuda:0')
# 238 2 tensor(5.9604, device='cuda:0', grad_fn=<DivBackward0>) tensor(339292, device='cuda:0')
# 239 2 tensor(5.9589, device='cuda:0', grad_fn=<DivBackward0>) tensor(340728, device='cuda:0')
# 240 2 tensor(5.9594, device='cuda:0', grad_fn=<DivBackward0>) tensor(342051, device='cuda:0')
# 241 2 tensor(5.9594, device='cuda:0', grad_fn=<DivBackward0>) tensor(342826, device='cuda:0')
# 242 2 tensor(5.9584, device='cuda:0', grad_fn=<DivBackward0>) tensor(343929, device='cuda:0')
# 243 2 tensor(5.9597, device='cuda:0', grad_fn=<DivBackward0>) tensor(345754, device='cuda:0')
# 244 2 tensor(5.9621, device='cuda:0', grad_fn=<DivBackward0>) tensor(347552, device='cuda:0')
# 245 2 tensor(5.9620, device='cuda:0', grad_fn=<DivBackward0>) tensor(349317, device='cuda:0')
# 246 2 tensor(5.9602, device='cuda:0', grad_fn=<DivBackward0>) tensor(351154, device='cuda:0')
# 247 2 tensor(5.9612, device='cuda:0', grad_fn=<DivBackward0>) tensor(353024, device='cuda:0')
# 248 2 tensor(5.9631, device='cuda:0', grad_fn=<DivBackward0>) tensor(354349, device='cuda:0')
# 249 2 tensor(5.9638, device='cuda:0', grad_fn=<DivBackward0>) tensor(355197, device='cuda:0')
# 250 2 tensor(5.9649, device='cuda:0', grad_fn=<DivBackward0>) tensor(356161, device='cuda:0')
# 251 2 tensor(5.9650, device='cuda:0', grad_fn=<DivBackward0>) tensor(357388, device='cuda:0')
# 252 2 tensor(5.9636, device='cuda:0', grad_fn=<DivBackward0>) tensor(359220, device='cuda:0')
# 253 2 tensor(5.9645, device='cuda:0', grad_fn=<DivBackward0>) tensor(361266, device='cuda:0')
# 254 2 tensor(5.9660, device='cuda:0', grad_fn=<DivBackward0>) tensor(363056, device='cuda:0')
# 255 2 tensor(5.9648, device='cuda:0', grad_fn=<DivBackward0>) tensor(364846, device='cuda:0')
# 256 2 tensor(5.9635, device='cuda:0', grad_fn=<DivBackward0>) tensor(366892, device='cuda:0')
# 257 2 tensor(5.9624, device='cuda:0', grad_fn=<DivBackward0>) tensor(368265, device='cuda:0')
# 258 2 tensor(5.9630, device='cuda:0', grad_fn=<DivBackward0>) tensor(368988, device='cuda:0')
# 259 2 tensor(5.9627, device='cuda:0', grad_fn=<DivBackward0>) tensor(370384, device='cuda:0')
# 260 2 tensor(5.9612, device='cuda:0', grad_fn=<DivBackward0>) tensor(372430, device='cuda:0')
# 261 2 tensor(5.9611, device='cuda:0', grad_fn=<DivBackward0>) tensor(374208, device='cuda:0')
# 262 2 tensor(5.9620, device='cuda:0', grad_fn=<DivBackward0>) tensor(375986, device='cuda:0')
# 263 2 tensor(5.9645, device='cuda:0', grad_fn=<DivBackward0>) tensor(378032, device='cuda:0')
# 264 2 tensor(5.9666, device='cuda:0', grad_fn=<DivBackward0>) tensor(379401, device='cuda:0')
# 265 2 tensor(5.9663, device='cuda:0', grad_fn=<DivBackward0>) tensor(380360, device='cuda:0')
# 266 2 tensor(5.9655, device='cuda:0', grad_fn=<DivBackward0>) tensor(381430, device='cuda:0')
# 267 2 tensor(5.9648, device='cuda:0', grad_fn=<DivBackward0>) tensor(382782, device='cuda:0')
# 268 2 tensor(5.9622, device='cuda:0', grad_fn=<DivBackward0>) tensor(384700, device='cuda:0')
# 269 2 tensor(5.9598, device='cuda:0', grad_fn=<DivBackward0>) tensor(386025, device='cuda:0')
# 270 2 tensor(5.9597, device='cuda:0', grad_fn=<DivBackward0>) tensor(386814, device='cuda:0')
# 271 2 tensor(5.9600, device='cuda:0', grad_fn=<DivBackward0>) tensor(387748, device='cuda:0')
# 272 2 tensor(5.9603, device='cuda:0', grad_fn=<DivBackward0>) tensor(388422, device='cuda:0')
# 273 2 tensor(5.9597, device='cuda:0', grad_fn=<DivBackward0>) tensor(389672, device='cuda:0')
# 274 2 tensor(5.9605, device='cuda:0', grad_fn=<DivBackward0>) tensor(391718, device='cuda:0')
# 275 2 tensor(5.9634, device='cuda:0', grad_fn=<DivBackward0>) tensor(393502, device='cuda:0')
# 276 2 tensor(5.9636, device='cuda:0', grad_fn=<DivBackward0>) tensor(395128, device='cuda:0')
# 277 2 tensor(5.9619, device='cuda:0', grad_fn=<DivBackward0>) tensor(396375, device='cuda:0')
# 278 2 tensor(5.9622, device='cuda:0', grad_fn=<DivBackward0>) tensor(396938, device='cuda:0')
# 279 2 tensor(5.9624, device='cuda:0', grad_fn=<DivBackward0>) tensor(397928, device='cuda:0')
# 280 2 tensor(5.9620, device='cuda:0', grad_fn=<DivBackward0>) tensor(399166, device='cuda:0')
# 281 2 tensor(5.9615, device='cuda:0', grad_fn=<DivBackward0>) tensor(400172, device='cuda:0')
# 282 2 tensor(5.9615, device='cuda:0', grad_fn=<DivBackward0>) tensor(400971, device='cuda:0')
# 283 2 tensor(5.9623, device='cuda:0', grad_fn=<DivBackward0>) tensor(402216, device='cuda:0')
# 284 2 tensor(5.9622, device='cuda:0', grad_fn=<DivBackward0>) tensor(403716, device='cuda:0')
# 285 2 tensor(5.9621, device='cuda:0', grad_fn=<DivBackward0>) tensor(404390, device='cuda:0')
# 286 2 tensor(5.9622, device='cuda:0', grad_fn=<DivBackward0>) tensor(405354, device='cuda:0')
# 287 2 tensor(5.9616, device='cuda:0', grad_fn=<DivBackward0>) tensor(407144, device='cuda:0')
# 288 2 tensor(5.9620, device='cuda:0', grad_fn=<DivBackward0>) tensor(409190, device='cuda:0')
# 289 2 tensor(5.9631, device='cuda:0', grad_fn=<DivBackward0>) tensor(410464, device='cuda:0')
# 290 2 tensor(5.9627, device='cuda:0', grad_fn=<DivBackward0>) tensor(411738, device='cuda:0')
# 291 2 tensor(5.9625, device='cuda:0', grad_fn=<DivBackward0>) tensor(413123, device='cuda:0')
# 292 2 tensor(5.9610, device='cuda:0', grad_fn=<DivBackward0>) tensor(414459, device='cuda:0')
# 293 2 tensor(5.9570, device='cuda:0', grad_fn=<DivBackward0>) tensor(416456, device='cuda:0')
# 294 2 tensor(5.9548, device='cuda:0', grad_fn=<DivBackward0>) tensor(417737, device='cuda:0')
# 295 2 tensor(5.9550, device='cuda:0', grad_fn=<DivBackward0>) tensor(419018, device='cuda:0')
# 296 2 tensor(5.9559, device='cuda:0', grad_fn=<DivBackward0>) tensor(420912, device='cuda:0')
# 297 2 tensor(5.9555, device='cuda:0', grad_fn=<DivBackward0>) tensor(422806, device='cuda:0')
# 298 2 tensor(5.9553, device='cuda:0', grad_fn=<DivBackward0>) tensor(424036, device='cuda:0')
# 299 2 tensor(5.9570, device='cuda:0', grad_fn=<DivBackward0>) tensor(425266, device='cuda:0')
# 300 2 tensor(5.9579, device='cuda:0', grad_fn=<DivBackward0>) tensor(426759, device='cuda:0')
# 301 2 tensor(5.9572, device='cuda:0', grad_fn=<DivBackward0>) tensor(428242, device='cuda:0')
# 302 2 tensor(5.9569, device='cuda:0', grad_fn=<DivBackward0>) tensor(429545, device='cuda:0')
# 303 2 tensor(5.9574, device='cuda:0', grad_fn=<DivBackward0>) tensor(430858, device='cuda:0')
# 304 2 tensor(5.9563, device='cuda:0', grad_fn=<DivBackward0>) tensor(432904, device='cuda:0')
# 305 2 tensor(5.9545, device='cuda:0', grad_fn=<DivBackward0>) tensor(434444, device='cuda:0')
# 306 2 tensor(5.9533, device='cuda:0', grad_fn=<DivBackward0>) tensor(435984, device='cuda:0')
# 307 2 tensor(5.9526, device='cuda:0', grad_fn=<DivBackward0>) tensor(438030, device='cuda:0')
# 308 2 tensor(5.9524, device='cuda:0', grad_fn=<DivBackward0>) tensor(439228, device='cuda:0')
# 309 2 tensor(5.9524, device='cuda:0', grad_fn=<DivBackward0>) tensor(439599, device='cuda:0')
# 310 2 tensor(5.9522, device='cuda:0', grad_fn=<DivBackward0>) tensor(440240, device='cuda:0')
# 311 2 tensor(5.9505, device='cuda:0', grad_fn=<DivBackward0>) tensor(441708, device='cuda:0')
# 312 2 tensor(5.9495, device='cuda:0', grad_fn=<DivBackward0>) tensor(443032, device='cuda:0')
# 313 2 tensor(5.9490, device='cuda:0', grad_fn=<DivBackward0>) tensor(444356, device='cuda:0')
# 314 2 tensor(5.9477, device='cuda:0', grad_fn=<DivBackward0>) tensor(445620, device='cuda:0')
# 315 2 tensor(5.9482, device='cuda:0', grad_fn=<DivBackward0>) tensor(446884, device='cuda:0')
# 316 2 tensor(5.9487, device='cuda:0', grad_fn=<DivBackward0>) tensor(448930, device='cuda:0')
# 317 2 tensor(5.9484, device='cuda:0', grad_fn=<DivBackward0>) tensor(450662, device='cuda:0')
# 318 2 tensor(5.9486, device='cuda:0', grad_fn=<DivBackward0>) tensor(452394, device='cuda:0')
# 319 2 tensor(5.9489, device='cuda:0', grad_fn=<DivBackward0>) tensor(454087, device='cuda:0')
# 320 2 tensor(5.9500, device='cuda:0', grad_fn=<DivBackward0>) tensor(455780, device='cuda:0')
# 321 2 tensor(5.9509, device='cuda:0', grad_fn=<DivBackward0>) tensor(457187, device='cuda:0')
# 322 2 tensor(5.9513, device='cuda:0', grad_fn=<DivBackward0>) tensor(458089, device='cuda:0')
# 323 2 tensor(5.9512, device='cuda:0', grad_fn=<DivBackward0>) tensor(459630, device='cuda:0')
# 324 2 tensor(5.9506, device='cuda:0', grad_fn=<DivBackward0>) tensor(461612, device='cuda:0')
# 325 2 tensor(5.9499, device='cuda:0', grad_fn=<DivBackward0>) tensor(463367, device='cuda:0')
# 326 2 tensor(5.9479, device='cuda:0', grad_fn=<DivBackward0>) tensor(465186, device='cuda:0')
# 327 2 tensor(5.9467, device='cuda:0', grad_fn=<DivBackward0>) tensor(467232, device='cuda:0')
# 328 2 tensor(5.9459, device='cuda:0', grad_fn=<DivBackward0>) tensor(469278, device='cuda:0')
# 329 2 tensor(5.9447, device='cuda:0', grad_fn=<DivBackward0>) tensor(470692, device='cuda:0')
# 330 2 tensor(5.9439, device='cuda:0', grad_fn=<DivBackward0>) tensor(472106, device='cuda:0')
# 331 2 tensor(5.9423, device='cuda:0', grad_fn=<DivBackward0>) tensor(474152, device='cuda:0')
# 332 2 tensor(5.9400, device='cuda:0', grad_fn=<DivBackward0>) tensor(476198, device='cuda:0')
# 333 2 tensor(5.9382, device='cuda:0', grad_fn=<DivBackward0>) tensor(477793, device='cuda:0')
# 334 2 tensor(5.9367, device='cuda:0', grad_fn=<DivBackward0>) tensor(479388, device='cuda:0')
# 335 2 tensor(5.9360, device='cuda:0', grad_fn=<DivBackward0>) tensor(480890, device='cuda:0')
# 336 2 tensor(5.9361, device='cuda:0', grad_fn=<DivBackward0>) tensor(481658, device='cuda:0')
# 337 2 tensor(5.9343, device='cuda:0', grad_fn=<DivBackward0>) tensor(482970, device='cuda:0')
# 338 2 tensor(5.9329, device='cuda:0', grad_fn=<DivBackward0>) tensor(484551, device='cuda:0')
# 339 2 tensor(5.9337, device='cuda:0', grad_fn=<DivBackward0>) tensor(485680, device='cuda:0')
# 340 2 tensor(5.9339, device='cuda:0', grad_fn=<DivBackward0>) tensor(487274, device='cuda:0')
# 341 2 tensor(5.9334, device='cuda:0', grad_fn=<DivBackward0>) tensor(489320, device='cuda:0')
# 342 2 tensor(5.9333, device='cuda:0', grad_fn=<DivBackward0>) tensor(491366, device='cuda:0')
# 343 2 tensor(5.9332, device='cuda:0', grad_fn=<DivBackward0>) tensor(492689, device='cuda:0')
# 344 2 tensor(5.9335, device='cuda:0', grad_fn=<DivBackward0>) tensor(494012, device='cuda:0')
# 345 2 tensor(5.9347, device='cuda:0', grad_fn=<DivBackward0>) tensor(495640, device='cuda:0')
# 346 2 tensor(5.9358, device='cuda:0', grad_fn=<DivBackward0>) tensor(496887, device='cuda:0')
# 347 2 tensor(5.9358, device='cuda:0', grad_fn=<DivBackward0>) tensor(498552, device='cuda:0')
# 348 2 tensor(5.9360, device='cuda:0', grad_fn=<DivBackward0>) tensor(500041, device='cuda:0')
# 349 2 tensor(5.9367, device='cuda:0', grad_fn=<DivBackward0>) tensor(501039, device='cuda:0')
# 350 2 tensor(5.9365, device='cuda:0', grad_fn=<DivBackward0>) tensor(502099, device='cuda:0')
# 351 2 tensor(5.9374, device='cuda:0', grad_fn=<DivBackward0>) tensor(503650, device='cuda:0')
# 352 2 tensor(5.9391, device='cuda:0', grad_fn=<DivBackward0>) tensor(505074, device='cuda:0')
# 353 2 tensor(5.9398, device='cuda:0', grad_fn=<DivBackward0>) tensor(505660, device='cuda:0')
# 354 2 tensor(5.9391, device='cuda:0', grad_fn=<DivBackward0>) tensor(506183, device='cuda:0')
# 355 2 tensor(5.9382, device='cuda:0', grad_fn=<DivBackward0>) tensor(506854, device='cuda:0')
# 356 2 tensor(5.9383, device='cuda:0', grad_fn=<DivBackward0>) tensor(507684, device='cuda:0')
# 357 2 tensor(5.9380, device='cuda:0', grad_fn=<DivBackward0>) tensor(509204, device='cuda:0')
# 358 2 tensor(5.9374, device='cuda:0', grad_fn=<DivBackward0>) tensor(511250, device='cuda:0')
# 359 2 tensor(5.9367, device='cuda:0', grad_fn=<DivBackward0>) tensor(513296, device='cuda:0')
# 360 2 tensor(5.9376, device='cuda:0', grad_fn=<DivBackward0>) tensor(514898, device='cuda:0')
# 361 2 tensor(5.9395, device='cuda:0', grad_fn=<DivBackward0>) tensor(516500, device='cuda:0')
# 362 2 tensor(5.9395, device='cuda:0', grad_fn=<DivBackward0>) tensor(518546, device='cuda:0')
# 363 2 tensor(5.9387, device='cuda:0', grad_fn=<DivBackward0>) tensor(520592, device='cuda:0')
# 364 2 tensor(5.9381, device='cuda:0', grad_fn=<DivBackward0>) tensor(522183, device='cuda:0')
# 365 2 tensor(5.9370, device='cuda:0', grad_fn=<DivBackward0>) tensor(523774, device='cuda:0')
# 366 2 tensor(5.9362, device='cuda:0', grad_fn=<DivBackward0>) tensor(524985, device='cuda:0')
# 367 2 tensor(5.9365, device='cuda:0', grad_fn=<DivBackward0>) tensor(525359, device='cuda:0')
# 368 2 tensor(5.9362, device='cuda:0', grad_fn=<DivBackward0>) tensor(526183, device='cuda:0')
# 369 2 tensor(5.9357, device='cuda:0', grad_fn=<DivBackward0>) tensor(527018, device='cuda:0')
# 370 2 tensor(5.9366, device='cuda:0', grad_fn=<DivBackward0>) tensor(528021, device='cuda:0')
# 371 2 tensor(5.9377, device='cuda:0', grad_fn=<DivBackward0>) tensor(529332, device='cuda:0')
# 372 2 tensor(5.9382, device='cuda:0', grad_fn=<DivBackward0>) tensor(530860, device='cuda:0')
# 373 2 tensor(5.9388, device='cuda:0', grad_fn=<DivBackward0>) tensor(532906, device='cuda:0')
# 374 2 tensor(5.9385, device='cuda:0', grad_fn=<DivBackward0>) tensor(534409, device='cuda:0')
# 375 2 tensor(5.9384, device='cuda:0', grad_fn=<DivBackward0>) tensor(535912, device='cuda:0')
# 376 2 tensor(5.9384, device='cuda:0', grad_fn=<DivBackward0>) tensor(537958, device='cuda:0')
# 377 2 tensor(5.9376, device='cuda:0', grad_fn=<DivBackward0>) tensor(539400, device='cuda:0')
# 378 2 tensor(5.9362, device='cuda:0', grad_fn=<DivBackward0>) tensor(540842, device='cuda:0')
# 379 2 tensor(5.9357, device='cuda:0', grad_fn=<DivBackward0>) tensor(542888, device='cuda:0')
# 380 2 tensor(5.9358, device='cuda:0', grad_fn=<DivBackward0>) tensor(544337, device='cuda:0')
# 381 2 tensor(5.9356, device='cuda:0', grad_fn=<DivBackward0>) tensor(544911, device='cuda:0')
# 382 2 tensor(5.9358, device='cuda:0', grad_fn=<DivBackward0>) tensor(545311, device='cuda:0')
# 383 2 tensor(5.9354, device='cuda:0', grad_fn=<DivBackward0>) tensor(546327, device='cuda:0')
# 384 2 tensor(5.9352, device='cuda:0', grad_fn=<DivBackward0>) tensor(547470, device='cuda:0')
# 385 2 tensor(5.9346, device='cuda:0', grad_fn=<DivBackward0>) tensor(548872, device='cuda:0')
# 386 2 tensor(5.9336, device='cuda:0', grad_fn=<DivBackward0>) tensor(550348, device='cuda:0')
# 387 2 tensor(5.9337, device='cuda:0', grad_fn=<DivBackward0>) tensor(551824, device='cuda:0')
# 388 2 tensor(5.9336, device='cuda:0', grad_fn=<DivBackward0>) tensor(553870, device='cuda:0')
# 389 2 tensor(5.9331, device='cuda:0', grad_fn=<DivBackward0>) tensor(555133, device='cuda:0')
# 390 2 tensor(5.9329, device='cuda:0', grad_fn=<DivBackward0>) tensor(556396, device='cuda:0')
# 391 2 tensor(5.9326, device='cuda:0', grad_fn=<DivBackward0>) tensor(557802, device='cuda:0')
# 392 2 tensor(5.9324, device='cuda:0', grad_fn=<DivBackward0>) tensor(558465, device='cuda:0')
# 393 2 tensor(5.9312, device='cuda:0', grad_fn=<DivBackward0>) tensor(559737, device='cuda:0')
# 394 2 tensor(5.9297, device='cuda:0', grad_fn=<DivBackward0>) tensor(560946, device='cuda:0')
# 395 2 tensor(5.9292, device='cuda:0', grad_fn=<DivBackward0>) tensor(561491, device='cuda:0')
# 396 2 tensor(5.9286, device='cuda:0', grad_fn=<DivBackward0>) tensor(562300, device='cuda:0')
# 397 2 tensor(5.9287, device='cuda:0', grad_fn=<DivBackward0>) tensor(563804, device='cuda:0')
# 398 2 tensor(5.9294, device='cuda:0', grad_fn=<DivBackward0>) tensor(565760, device='cuda:0')
# 399 2 tensor(5.9295, device='cuda:0', grad_fn=<DivBackward0>) tensor(566873, device='cuda:0')
# 400 2 tensor(5.9297, device='cuda:0', grad_fn=<DivBackward0>) tensor(567655, device='cuda:0')
# 401 2 tensor(5.9298, device='cuda:0', grad_fn=<DivBackward0>) tensor(569280, device='cuda:0')
# 402 2 tensor(5.9298, device='cuda:0', grad_fn=<DivBackward0>) tensor(570748, device='cuda:0')
# 403 2 tensor(5.9299, device='cuda:0', grad_fn=<DivBackward0>) tensor(571958, device='cuda:0')
# 404 2 tensor(5.9304, device='cuda:0', grad_fn=<DivBackward0>) tensor(573746, device='cuda:0')
# 405 2 tensor(5.9307, device='cuda:0', grad_fn=<DivBackward0>) tensor(575294, device='cuda:0')
# 406 2 tensor(5.9306, device='cuda:0', grad_fn=<DivBackward0>) tensor(576121, device='cuda:0')
# 407 2 tensor(5.9301, device='cuda:0', grad_fn=<DivBackward0>) tensor(576880, device='cuda:0')
# 408 2 tensor(5.9286, device='cuda:0', grad_fn=<DivBackward0>) tensor(578360, device='cuda:0')
# 409 2 tensor(5.9278, device='cuda:0', grad_fn=<DivBackward0>) tensor(579597, device='cuda:0')
# 410 2 tensor(5.9276, device='cuda:0', grad_fn=<DivBackward0>) tensor(580702, device='cuda:0')
# 411 2 tensor(5.9273, device='cuda:0', grad_fn=<DivBackward0>) tensor(582616, device='cuda:0')
# 412 2 tensor(5.9278, device='cuda:0', grad_fn=<DivBackward0>) tensor(584438, device='cuda:0')
# 413 2 tensor(5.9279, device='cuda:0', grad_fn=<DivBackward0>) tensor(585927, device='cuda:0')
# 414 2 tensor(5.9272, device='cuda:0', grad_fn=<DivBackward0>) tensor(587221, device='cuda:0')
# 415 2 tensor(5.9271, device='cuda:0', grad_fn=<DivBackward0>) tensor(588246, device='cuda:0')
# 416 2 tensor(5.9280, device='cuda:0', grad_fn=<DivBackward0>) tensor(589061, device='cuda:0')
# 417 2 tensor(5.9289, device='cuda:0', grad_fn=<DivBackward0>) tensor(589665, device='cuda:0')
# 418 2 tensor(5.9298, device='cuda:0', grad_fn=<DivBackward0>) tensor(590898, device='cuda:0')
# 419 2 tensor(5.9308, device='cuda:0', grad_fn=<DivBackward0>) tensor(592944, device='cuda:0')
# 420 2 tensor(5.9313, device='cuda:0', grad_fn=<DivBackward0>) tensor(594990, device='cuda:0')
# 421 2 tensor(5.9311, device='cuda:0', grad_fn=<DivBackward0>) tensor(596688, device='cuda:0')
# 422 2 tensor(5.9314, device='cuda:0', grad_fn=<DivBackward0>) tensor(598386, device='cuda:0')
# 423 2 tensor(5.9317, device='cuda:0', grad_fn=<DivBackward0>) tensor(600047, device='cuda:0')
# 424 2 tensor(5.9318, device='cuda:0', grad_fn=<DivBackward0>) tensor(601040, device='cuda:0')
# 425 2 tensor(5.9302, device='cuda:0', grad_fn=<DivBackward0>) tensor(602418, device='cuda:0')
# 426 2 tensor(5.9285, device='cuda:0', grad_fn=<DivBackward0>) tensor(603853, device='cuda:0')
# 427 2 tensor(5.9284, device='cuda:0', grad_fn=<DivBackward0>) tensor(604511, device='cuda:0')
# 428 2 tensor(5.9287, device='cuda:0', grad_fn=<DivBackward0>) tensor(605104, device='cuda:0')
# 429 2 tensor(5.9287, device='cuda:0', grad_fn=<DivBackward0>) tensor(606215, device='cuda:0')
# 430 2 tensor(5.9285, device='cuda:0', grad_fn=<DivBackward0>) tensor(607356, device='cuda:0')
# 431 2 tensor(5.9280, device='cuda:0', grad_fn=<DivBackward0>) tensor(608176, device='cuda:0')
# 432 2 tensor(5.9275, device='cuda:0', grad_fn=<DivBackward0>) tensor(608838, device='cuda:0')
# 433 2 tensor(5.9273, device='cuda:0', grad_fn=<DivBackward0>) tensor(609585, device='cuda:0')
# 434 2 tensor(5.9286, device='cuda:0', grad_fn=<DivBackward0>) tensor(611136, device='cuda:0')
# 435 2 tensor(5.9304, device='cuda:0', grad_fn=<DivBackward0>) tensor(612547, device='cuda:0')
# 436 2 tensor(5.9305, device='cuda:0', grad_fn=<DivBackward0>) tensor(613326, device='cuda:0')
# 437 2 tensor(5.9304, device='cuda:0', grad_fn=<DivBackward0>) tensor(613947, device='cuda:0')
# 438 2 tensor(5.9305, device='cuda:0', grad_fn=<DivBackward0>) tensor(615200, device='cuda:0')
# 439 2 tensor(5.9307, device='cuda:0', grad_fn=<DivBackward0>) tensor(616991, device='cuda:0')
# 440 2 tensor(5.9310, device='cuda:0', grad_fn=<DivBackward0>) tensor(618782, device='cuda:0')
# 441 2 tensor(5.9311, device='cuda:0', grad_fn=<DivBackward0>) tensor(620828, device='cuda:0')
# 442 2 tensor(5.9310, device='cuda:0', grad_fn=<DivBackward0>) tensor(622091, device='cuda:0')
# 443 2 tensor(5.9309, device='cuda:0', grad_fn=<DivBackward0>) tensor(623354, device='cuda:0')
# 444 2 tensor(5.9312, device='cuda:0', grad_fn=<DivBackward0>) tensor(625400, device='cuda:0')
# 445 2 tensor(5.9308, device='cuda:0', grad_fn=<DivBackward0>) tensor(626800, device='cuda:0')
# 446 2 tensor(5.9301, device='cuda:0', grad_fn=<DivBackward0>) tensor(628180, device='cuda:0')
# 447 2 tensor(5.9301, device='cuda:0', grad_fn=<DivBackward0>) tensor(630206, device='cuda:0')
# 448 2 tensor(5.9320, device='cuda:0', grad_fn=<DivBackward0>) tensor(632001, device='cuda:0')
# 449 2 tensor(5.9327, device='cuda:0', grad_fn=<DivBackward0>) tensor(633796, device='cuda:0')
# 450 2 tensor(5.9312, device='cuda:0', grad_fn=<DivBackward0>) tensor(635842, device='cuda:0')
# 451 2 tensor(5.9308, device='cuda:0', grad_fn=<DivBackward0>) tensor(637082, device='cuda:0')
# 452 2 tensor(5.9313, device='cuda:0', grad_fn=<DivBackward0>) tensor(637769, device='cuda:0')
# 453 2 tensor(5.9325, device='cuda:0', grad_fn=<DivBackward0>) tensor(639262, device='cuda:0')
# 454 2 tensor(5.9335, device='cuda:0', grad_fn=<DivBackward0>) tensor(641308, device='cuda:0')
# 455 2 tensor(5.9332, device='cuda:0', grad_fn=<DivBackward0>) tensor(643063, device='cuda:0')
# 456 2 tensor(5.9331, device='cuda:0', grad_fn=<DivBackward0>) tensor(644818, device='cuda:0')
# 457 2 tensor(5.9351, device='cuda:0', grad_fn=<DivBackward0>) tensor(646760, device='cuda:0')
# 458 2 tensor(5.9360, device='cuda:0', grad_fn=<DivBackward0>) tensor(648702, device='cuda:0')
# 459 2 tensor(5.9353, device='cuda:0', grad_fn=<DivBackward0>) tensor(650748, device='cuda:0')
# 460 2 tensor(5.9354, device='cuda:0', grad_fn=<DivBackward0>) tensor(652018, device='cuda:0')
# 461 2 tensor(5.9345, device='cuda:0', grad_fn=<DivBackward0>) tensor(653288, device='cuda:0')
# 462 2 tensor(5.9329, device='cuda:0', grad_fn=<DivBackward0>) tensor(655334, device='cuda:0')
# 463 2 tensor(5.9328, device='cuda:0', grad_fn=<DivBackward0>) tensor(657380, device='cuda:0')
# 464 2 tensor(5.9329, device='cuda:0', grad_fn=<DivBackward0>) tensor(659426, device='cuda:0')
# 465 2 tensor(5.9328, device='cuda:0', grad_fn=<DivBackward0>) tensor(661472, device='cuda:0')
# 466 2 tensor(5.9332, device='cuda:0', grad_fn=<DivBackward0>) tensor(663197, device='cuda:0')
# 467 2 tensor(5.9324, device='cuda:0', grad_fn=<DivBackward0>) tensor(664468, device='cuda:0')
# 468 2 tensor(5.9313, device='cuda:0', grad_fn=<DivBackward0>) tensor(665676, device='cuda:0')
# 469 2 tensor(5.9307, device='cuda:0', grad_fn=<DivBackward0>) tensor(666712, device='cuda:0')
# 470 2 tensor(5.9306, device='cuda:0', grad_fn=<DivBackward0>) tensor(668132, device='cuda:0')
# 471 2 tensor(5.9305, device='cuda:0', grad_fn=<DivBackward0>) tensor(669850, device='cuda:0')
# 472 2 tensor(5.9311, device='cuda:0', grad_fn=<DivBackward0>) tensor(671568, device='cuda:0')
# 473 2 tensor(5.9316, device='cuda:0', grad_fn=<DivBackward0>) tensor(672897, device='cuda:0')
# 474 2 tensor(5.9318, device='cuda:0', grad_fn=<DivBackward0>) tensor(673789, device='cuda:0')
# 475 2 tensor(5.9322, device='cuda:0', grad_fn=<DivBackward0>) tensor(674818, device='cuda:0')
# 476 2 tensor(5.9324, device='cuda:0', grad_fn=<DivBackward0>) tensor(675719, device='cuda:0')
# 477 2 tensor(5.9320, device='cuda:0', grad_fn=<DivBackward0>) tensor(677200, device='cuda:0')
# 478 2 tensor(5.9319, device='cuda:0', grad_fn=<DivBackward0>) tensor(678801, device='cuda:0')
# 479 2 tensor(5.9326, device='cuda:0', grad_fn=<DivBackward0>) tensor(679743, device='cuda:0')
# 480 2 tensor(5.9339, device='cuda:0', grad_fn=<DivBackward0>) tensor(681130, device='cuda:0')
# 481 2 tensor(5.9347, device='cuda:0', grad_fn=<DivBackward0>) tensor(682941, device='cuda:0')
# 482 2 tensor(5.9341, device='cuda:0', grad_fn=<DivBackward0>) tensor(684752, device='cuda:0')
# 483 2 tensor(5.9331, device='cuda:0', grad_fn=<DivBackward0>) tensor(686798, device='cuda:0')
# 484 2 tensor(5.9328, device='cuda:0', grad_fn=<DivBackward0>) tensor(688123, device='cuda:0')
# 485 2 tensor(5.9331, device='cuda:0', grad_fn=<DivBackward0>) tensor(689159, device='cuda:0')
# 486 2 tensor(5.9330, device='cuda:0', grad_fn=<DivBackward0>) tensor(690392, device='cuda:0')
# 487 2 tensor(5.9325, device='cuda:0', grad_fn=<DivBackward0>) tensor(691914, device='cuda:0')
# 488 2 tensor(5.9321, device='cuda:0', grad_fn=<DivBackward0>) tensor(693101, device='cuda:0')
# 489 2 tensor(5.9323, device='cuda:0', grad_fn=<DivBackward0>) tensor(694288, device='cuda:0')
# 490 2 tensor(5.9323, device='cuda:0', grad_fn=<DivBackward0>) tensor(695652, device='cuda:0')
# 491 2 tensor(5.9322, device='cuda:0', grad_fn=<DivBackward0>) tensor(696228, device='cuda:0')
# 492 2 tensor(5.9323, device='cuda:0', grad_fn=<DivBackward0>) tensor(697208, device='cuda:0')
# 493 2 tensor(5.9325, device='cuda:0', grad_fn=<DivBackward0>) tensor(698188, device='cuda:0')
# 494 2 tensor(5.9323, device='cuda:0', grad_fn=<DivBackward0>) tensor(699344, device='cuda:0')
# 495 2 tensor(5.9317, device='cuda:0', grad_fn=<DivBackward0>) tensor(700963, device='cuda:0')
# 496 2 tensor(5.9311, device='cuda:0', grad_fn=<DivBackward0>) tensor(702102, device='cuda:0')
# 497 2 tensor(5.9303, device='cuda:0', grad_fn=<DivBackward0>) tensor(703305, device='cuda:0')
# 498 2 tensor(5.9292, device='cuda:0', grad_fn=<DivBackward0>) tensor(704626, device='cuda:0')
# 499 2 tensor(5.9282, device='cuda:0', grad_fn=<DivBackward0>) tensor(706208, device='cuda:0')
# 500 2 tensor(5.9283, device='cuda:0', grad_fn=<DivBackward0>) tensor(708104, device='cuda:0')
# 501 2 tensor(5.9286, device='cuda:0', grad_fn=<DivBackward0>) tensor(709561, device='cuda:0')
# 502 2 tensor(5.9281, device='cuda:0', grad_fn=<DivBackward0>) tensor(711083, device='cuda:0')
# 503 2 tensor(5.9277, device='cuda:0', grad_fn=<DivBackward0>) tensor(712359, device='cuda:0')
# 504 2 tensor(5.9280, device='cuda:0', grad_fn=<DivBackward0>) tensor(713570, device='cuda:0')
# 505 2 tensor(5.9283, device='cuda:0', grad_fn=<DivBackward0>) tensor(715379, device='cuda:0')
# 506 2 tensor(5.9286, device='cuda:0', grad_fn=<DivBackward0>) tensor(716812, device='cuda:0')
# 507 2 tensor(5.9291, device='cuda:0', grad_fn=<DivBackward0>) tensor(718036, device='cuda:0')
# 508 2 tensor(5.9294, device='cuda:0', grad_fn=<DivBackward0>) tensor(719067, device='cuda:0')
# 509 2 tensor(5.9290, device='cuda:0', grad_fn=<DivBackward0>) tensor(720394, device='cuda:0')
# 510 2 tensor(5.9289, device='cuda:0', grad_fn=<DivBackward0>) tensor(722275, device='cuda:0')
# 511 2 tensor(5.9293, device='cuda:0', grad_fn=<DivBackward0>) tensor(723335, device='cuda:0')
# 512 2 tensor(5.9294, device='cuda:0', grad_fn=<DivBackward0>) tensor(724157, device='cuda:0')
# ...
# 3835 2 tensor(5.7779, device='cuda:0', grad_fn=<DivBackward0>) tensor(5306250, device='cuda:0')
# 3836 2 tensor(5.7779, device='cuda:0', grad_fn=<DivBackward0>) tensor(5308162, device='cuda:0')
# 3837 2 tensor(5.7779, device='cuda:0', grad_fn=<DivBackward0>) tensor(5309536, device='cuda:0')
# 3838 2 tensor(5.7779, device='cuda:0', grad_fn=<DivBackward0>) tensor(5311044, device='cuda:0')
# 3839 2 tensor(5.7779, device='cuda:0', grad_fn=<DivBackward0>) tensor(5312450, device='cuda:0')
# 3840 2 tensor(5.7780, device='cuda:0', grad_fn=<DivBackward0>) tensor(5313427, device='cuda:0')
# 3841 2 tensor(5.7781, device='cuda:0', grad_fn=<DivBackward0>) tensor(5314728, device='cuda:0')
# 3842 2 tensor(5.7781, device='cuda:0', grad_fn=<DivBackward0>) tensor(5316458, device='cuda:0')
# 3843 2 tensor(5.7780, device='cuda:0', grad_fn=<DivBackward0>) tensor(5318020, device='cuda:0')
# 3844 2 tensor(5.7779, device='cuda:0', grad_fn=<DivBackward0>) tensor(5319367, device='cuda:0')
# 3845 2 tensor(5.7779, device='cuda:0', grad_fn=<DivBackward0>) tensor(5320987, device='cuda:0')
# 3846 2 tensor(5.7778, device='cuda:0', grad_fn=<DivBackward0>) tensor(5322146, device='cuda:0')
# 3847 2 tensor(5.7778, device='cuda:0', grad_fn=<DivBackward0>) tensor(5323461, device='cuda:0')
# 3848 2 tensor(5.7779, device='cuda:0', grad_fn=<DivBackward0>) tensor(5324749, device='cuda:0')
# 3849 2 tensor(5.7781, device='cuda:0', grad_fn=<DivBackward0>) tensor(5326092, device='cuda:0')
# 3850 2 tensor(5.7784, device='cuda:0', grad_fn=<DivBackward0>) tensor(5328138, device='cuda:0')
# 3851 2 tensor(5.7786, device='cuda:0', grad_fn=<DivBackward0>) tensor(5329830, device='cuda:0')
# 3852 2 tensor(5.7788, device='cuda:0', grad_fn=<DivBackward0>) tensor(5331048, device='cuda:0')
# 3853 2 tensor(5.7789, device='cuda:0', grad_fn=<DivBackward0>) tensor(5332620, device='cuda:0')
# 3854 2 tensor(5.7791, device='cuda:0', grad_fn=<DivBackward0>) tensor(5334122, device='cuda:0')
# 3855 2 tensor(5.7791, device='cuda:0', grad_fn=<DivBackward0>) tensor(5335481, device='cuda:0')
# 3856 2 tensor(5.7792, device='cuda:0', grad_fn=<DivBackward0>) tensor(5337384, device='cuda:0')
# 3857 2 tensor(5.7794, device='cuda:0', grad_fn=<DivBackward0>) tensor(5339168, device='cuda:0')
# 3858 2 tensor(5.7795, device='cuda:0', grad_fn=<DivBackward0>) tensor(5340877, device='cuda:0')
# 3859 2 tensor(5.7795, device='cuda:0', grad_fn=<DivBackward0>) tensor(5342696, device='cuda:0')
# 3860 2 tensor(5.7796, device='cuda:0', grad_fn=<DivBackward0>) tensor(5344590, device='cuda:0')
# 3861 2 tensor(5.7796, device='cuda:0', grad_fn=<DivBackward0>) tensor(5345920, device='cuda:0')
# 3862 2 tensor(5.7797, device='cuda:0', grad_fn=<DivBackward0>) tensor(5347250, device='cuda:0')
# 3863 2 tensor(5.7798, device='cuda:0', grad_fn=<DivBackward0>) tensor(5348848, device='cuda:0')
# 3864 2 tensor(5.7801, device='cuda:0', grad_fn=<DivBackward0>) tensor(5350446, device='cuda:0')
# 3865 2 tensor(5.7804, device='cuda:0', grad_fn=<DivBackward0>) tensor(5352071, device='cuda:0')
# 3866 2 tensor(5.7804, device='cuda:0', grad_fn=<DivBackward0>) tensor(5353013, device='cuda:0')
# 3867 2 tensor(5.7805, device='cuda:0', grad_fn=<DivBackward0>) tensor(5354376, device='cuda:0')
# 3868 2 tensor(5.7805, device='cuda:0', grad_fn=<DivBackward0>) tensor(5356422, device='cuda:0')
# 3869 2 tensor(5.7805, device='cuda:0', grad_fn=<DivBackward0>) tensor(5358154, device='cuda:0')
# 3870 2 tensor(5.7806, device='cuda:0', grad_fn=<DivBackward0>) tensor(5359724, device='cuda:0')
# 3871 2 tensor(5.7806, device='cuda:0', grad_fn=<DivBackward0>) tensor(5360801, device='cuda:0')
# 3872 2 tensor(5.7806, device='cuda:0', grad_fn=<DivBackward0>) tensor(5361939, device='cuda:0')
# 3873 2 tensor(5.7806, device='cuda:0', grad_fn=<DivBackward0>) tensor(5363884, device='cuda:0')
# 3874 2 tensor(5.7808, device='cuda:0', grad_fn=<DivBackward0>) tensor(5365930, device='cuda:0')
# 3875 2 tensor(5.7810, device='cuda:0', grad_fn=<DivBackward0>) tensor(5367193, device='cuda:0')
# 3876 2 tensor(5.7811, device='cuda:0', grad_fn=<DivBackward0>) tensor(5367617, device='cuda:0')
# 3877 2 tensor(5.7811, device='cuda:0', grad_fn=<DivBackward0>) tensor(5368824, device='cuda:0')
# 3878 2 tensor(5.7811, device='cuda:0', grad_fn=<DivBackward0>) tensor(5370353, device='cuda:0')
# 3879 2 tensor(5.7811, device='cuda:0', grad_fn=<DivBackward0>) tensor(5371098, device='cuda:0')
# 3880 2 tensor(5.7812, device='cuda:0', grad_fn=<DivBackward0>) tensor(5371850, device='cuda:0')
# 3881 2 tensor(5.7812, device='cuda:0', grad_fn=<DivBackward0>) tensor(5373386, device='cuda:0')
# 3882 2 tensor(5.7811, device='cuda:0', grad_fn=<DivBackward0>) tensor(5374639, device='cuda:0')
# 3883 2 tensor(5.7812, device='cuda:0', grad_fn=<DivBackward0>) tensor(5375236, device='cuda:0')
# 3884 2 tensor(5.7812, device='cuda:0', grad_fn=<DivBackward0>) tensor(5376082, device='cuda:0')
# 3885 2 tensor(5.7812, device='cuda:0', grad_fn=<DivBackward0>) tensor(5376899, device='cuda:0')
# 3886 2 tensor(5.7812, device='cuda:0', grad_fn=<DivBackward0>) tensor(5377907, device='cuda:0')
# 3887 2 tensor(5.7812, device='cuda:0', grad_fn=<DivBackward0>) tensor(5378890, device='cuda:0')
# 3888 2 tensor(5.7813, device='cuda:0', grad_fn=<DivBackward0>) tensor(5380226, device='cuda:0')
# 3889 2 tensor(5.7814, device='cuda:0', grad_fn=<DivBackward0>) tensor(5382042, device='cuda:0')
# 3890 2 tensor(5.7814, device='cuda:0', grad_fn=<DivBackward0>) tensor(5383858, device='cuda:0')
# 3891 2 tensor(5.7813, device='cuda:0', grad_fn=<DivBackward0>) tensor(5385904, device='cuda:0')
# 3892 2 tensor(5.7814, device='cuda:0', grad_fn=<DivBackward0>) tensor(5387698, device='cuda:0')
# 3893 2 tensor(5.7816, device='cuda:0', grad_fn=<DivBackward0>) tensor(5389309, device='cuda:0')
# 3894 2 tensor(5.7816, device='cuda:0', grad_fn=<DivBackward0>) tensor(5390454, device='cuda:0')
# 3895 2 tensor(5.7817, device='cuda:0', grad_fn=<DivBackward0>) tensor(5391009, device='cuda:0')
# 3896 2 tensor(5.7817, device='cuda:0', grad_fn=<DivBackward0>) tensor(5392282, device='cuda:0')
# 3897 2 tensor(5.7820, device='cuda:0', grad_fn=<DivBackward0>) tensor(5394328, device='cuda:0')
# 3898 2 tensor(5.7823, device='cuda:0', grad_fn=<DivBackward0>) tensor(5396374, device='cuda:0')
# 3899 2 tensor(5.7824, device='cuda:0', grad_fn=<DivBackward0>) tensor(5398420, device='cuda:0')
# 3900 2 tensor(5.7825, device='cuda:0', grad_fn=<DivBackward0>) tensor(5399871, device='cuda:0')
# 3901 2 tensor(5.7825, device='cuda:0', grad_fn=<DivBackward0>) tensor(5400835, device='cuda:0')
# 3902 2 tensor(5.7825, device='cuda:0', grad_fn=<DivBackward0>) tensor(5401657, device='cuda:0')
# 3903 2 tensor(5.7826, device='cuda:0', grad_fn=<DivBackward0>) tensor(5402171, device='cuda:0')
# 3904 2 tensor(5.7827, device='cuda:0', grad_fn=<DivBackward0>) tensor(5403422, device='cuda:0')
# 3905 2 tensor(5.7829, device='cuda:0', grad_fn=<DivBackward0>) tensor(5405468, device='cuda:0')
# 3906 2 tensor(5.7833, device='cuda:0', grad_fn=<DivBackward0>) tensor(5407452, device='cuda:0')
# 3907 2 tensor(5.7835, device='cuda:0', grad_fn=<DivBackward0>) tensor(5408937, device='cuda:0')
# 3908 2 tensor(5.7835, device='cuda:0', grad_fn=<DivBackward0>) tensor(5409920, device='cuda:0')
# 3909 2 tensor(5.7834, device='cuda:0', grad_fn=<DivBackward0>) tensor(5411402, device='cuda:0')
# 3910 2 tensor(5.7834, device='cuda:0', grad_fn=<DivBackward0>) tensor(5412638, device='cuda:0')
# 3911 2 tensor(5.7834, device='cuda:0', grad_fn=<DivBackward0>) tensor(5413330, device='cuda:0')
# 3912 2 tensor(5.7833, device='cuda:0', grad_fn=<DivBackward0>) tensor(5414832, device='cuda:0')
# 3913 2 tensor(5.7833, device='cuda:0', grad_fn=<DivBackward0>) tensor(5416878, device='cuda:0')
# 3914 2 tensor(5.7832, device='cuda:0', grad_fn=<DivBackward0>) tensor(5418178, device='cuda:0')
# 3915 2 tensor(5.7832, device='cuda:0', grad_fn=<DivBackward0>) tensor(5419478, device='cuda:0')
# 3916 2 tensor(5.7833, device='cuda:0', grad_fn=<DivBackward0>) tensor(5421012, device='cuda:0')
# 3917 2 tensor(5.7833, device='cuda:0', grad_fn=<DivBackward0>) tensor(5422089, device='cuda:0')
# 3918 2 tensor(5.7833, device='cuda:0', grad_fn=<DivBackward0>) tensor(5423193, device='cuda:0')
# 3919 2 tensor(5.7834, device='cuda:0', grad_fn=<DivBackward0>) tensor(5424128, device='cuda:0')
# 3920 2 tensor(5.7834, device='cuda:0', grad_fn=<DivBackward0>) tensor(5425048, device='cuda:0')
# 3921 2 tensor(5.7835, device='cuda:0', grad_fn=<DivBackward0>) tensor(5426594, device='cuda:0')
# 3922 2 tensor(5.7835, device='cuda:0', grad_fn=<DivBackward0>) tensor(5428080, device='cuda:0')
# 3923 2 tensor(5.7836, device='cuda:0', grad_fn=<DivBackward0>) tensor(5429245, device='cuda:0')
# 3924 2 tensor(5.7836, device='cuda:0', grad_fn=<DivBackward0>) tensor(5430139, device='cuda:0')
# 3925 2 tensor(5.7837, device='cuda:0', grad_fn=<DivBackward0>) tensor(5431354, device='cuda:0')
# 3926 2 tensor(5.7838, device='cuda:0', grad_fn=<DivBackward0>) tensor(5433121, device='cuda:0')
# 3927 2 tensor(5.7839, device='cuda:0', grad_fn=<DivBackward0>) tensor(5434888, device='cuda:0')
# 3928 2 tensor(5.7839, device='cuda:0', grad_fn=<DivBackward0>) tensor(5436292, device='cuda:0')
# 3929 2 tensor(5.7839, device='cuda:0', grad_fn=<DivBackward0>) tensor(5436856, device='cuda:0')
# 3930 2 tensor(5.7839, device='cuda:0', grad_fn=<DivBackward0>) tensor(5437817, device='cuda:0')
# 3931 2 tensor(5.7839, device='cuda:0', grad_fn=<DivBackward0>) tensor(5439618, device='cuda:0')
# 3932 2 tensor(5.7841, device='cuda:0', grad_fn=<DivBackward0>) tensor(5441087, device='cuda:0')
# 3933 2 tensor(5.7842, device='cuda:0', grad_fn=<DivBackward0>) tensor(5442374, device='cuda:0')
# 3934 2 tensor(5.7842, device='cuda:0', grad_fn=<DivBackward0>) tensor(5444238, device='cuda:0')
# 3935 2 tensor(5.7843, device='cuda:0', grad_fn=<DivBackward0>) tensor(5446036, device='cuda:0')
# 3936 2 tensor(5.7844, device='cuda:0', grad_fn=<DivBackward0>) tensor(5447834, device='cuda:0')
# 3937 2 tensor(5.7845, device='cuda:0', grad_fn=<DivBackward0>) tensor(5449131, device='cuda:0')
# 3938 2 tensor(5.7847, device='cuda:0', grad_fn=<DivBackward0>) tensor(5450400, device='cuda:0')
# 3939 2 tensor(5.7848, device='cuda:0', grad_fn=<DivBackward0>) tensor(5451702, device='cuda:0')
# 3940 2 tensor(5.7848, device='cuda:0', grad_fn=<DivBackward0>) tensor(5452191, device='cuda:0')
# 3941 2 tensor(5.7848, device='cuda:0', grad_fn=<DivBackward0>) tensor(5453396, device='cuda:0')
# 3942 2 tensor(5.7849, device='cuda:0', grad_fn=<DivBackward0>) tensor(5455442, device='cuda:0')
# 3943 2 tensor(5.7850, device='cuda:0', grad_fn=<DivBackward0>) tensor(5456660, device='cuda:0')
# 3944 2 tensor(5.7850, device='cuda:0', grad_fn=<DivBackward0>) tensor(5457643, device='cuda:0')
# 3945 2 tensor(5.7850, device='cuda:0', grad_fn=<DivBackward0>) tensor(5459454, device='cuda:0')
# 3946 2 tensor(5.7850, device='cuda:0', grad_fn=<DivBackward0>) tensor(5461316, device='cuda:0')
# 3947 2 tensor(5.7851, device='cuda:0', grad_fn=<DivBackward0>) tensor(5462955, device='cuda:0')
# 3948 2 tensor(5.7851, device='cuda:0', grad_fn=<DivBackward0>) tensor(5464778, device='cuda:0')
# 3949 2 tensor(5.7851, device='cuda:0', grad_fn=<DivBackward0>) tensor(5466600, device='cuda:0')
# 3950 2 tensor(5.7851, device='cuda:0', grad_fn=<DivBackward0>) tensor(5467638, device='cuda:0')
# 3951 2 tensor(5.7852, device='cuda:0', grad_fn=<DivBackward0>) tensor(5468506, device='cuda:0')
# 3952 2 tensor(5.7853, device='cuda:0', grad_fn=<DivBackward0>) tensor(5469714, device='cuda:0')
# 3953 2 tensor(5.7853, device='cuda:0', grad_fn=<DivBackward0>) tensor(5470718, device='cuda:0')
# 3954 2 tensor(5.7855, device='cuda:0', grad_fn=<DivBackward0>) tensor(5472067, device='cuda:0')
# 3955 2 tensor(5.7857, device='cuda:0', grad_fn=<DivBackward0>) tensor(5473639, device='cuda:0')
# 3956 2 tensor(5.7857, device='cuda:0', grad_fn=<DivBackward0>) tensor(5474769, device='cuda:0')
# 3957 2 tensor(5.7858, device='cuda:0', grad_fn=<DivBackward0>) tensor(5476059, device='cuda:0')
# 3958 2 tensor(5.7859, device='cuda:0', grad_fn=<DivBackward0>) tensor(5477890, device='cuda:0')
# 3959 2 tensor(5.7859, device='cuda:0', grad_fn=<DivBackward0>) tensor(5479828, device='cuda:0')
# 3960 2 tensor(5.7859, device='cuda:0', grad_fn=<DivBackward0>) tensor(5481764, device='cuda:0')
# 3961 2 tensor(5.7859, device='cuda:0', grad_fn=<DivBackward0>) tensor(5482969, device='cuda:0')
# 3962 2 tensor(5.7859, device='cuda:0', grad_fn=<DivBackward0>) tensor(5483609, device='cuda:0')
# 3963 2 tensor(5.7859, device='cuda:0', grad_fn=<DivBackward0>) tensor(5484305, device='cuda:0')
# 3964 2 tensor(5.7859, device='cuda:0', grad_fn=<DivBackward0>) tensor(5485257, device='cuda:0')
# 3965 2 tensor(5.7858, device='cuda:0', grad_fn=<DivBackward0>) tensor(5486992, device='cuda:0')
# 3966 2 tensor(5.7859, device='cuda:0', grad_fn=<DivBackward0>) tensor(5488408, device='cuda:0')
# 3967 2 tensor(5.7860, device='cuda:0', grad_fn=<DivBackward0>) tensor(5489824, device='cuda:0')
# 3968 2 tensor(5.7860, device='cuda:0', grad_fn=<DivBackward0>) tensor(5491538, device='cuda:0')
# 3969 2 tensor(5.7860, device='cuda:0', grad_fn=<DivBackward0>) tensor(5493252, device='cuda:0')
# 3970 2 tensor(5.7860, device='cuda:0', grad_fn=<DivBackward0>) tensor(5495298, device='cuda:0')
# 3971 2 tensor(5.7860, device='cuda:0', grad_fn=<DivBackward0>) tensor(5496715, device='cuda:0')
# 3972 2 tensor(5.7859, device='cuda:0', grad_fn=<DivBackward0>) tensor(5497853, device='cuda:0')
# 3973 2 tensor(5.7859, device='cuda:0', grad_fn=<DivBackward0>) tensor(5499455, device='cuda:0')
# 3974 2 tensor(5.7860, device='cuda:0', grad_fn=<DivBackward0>) tensor(5500875, device='cuda:0')
# 3975 2 tensor(5.7860, device='cuda:0', grad_fn=<DivBackward0>) tensor(5502183, device='cuda:0')
# 3976 2 tensor(5.7859, device='cuda:0', grad_fn=<DivBackward0>) tensor(5503122, device='cuda:0')
# 3977 2 tensor(5.7859, device='cuda:0', grad_fn=<DivBackward0>) tensor(5504032, device='cuda:0')
# 3978 2 tensor(5.7860, device='cuda:0', grad_fn=<DivBackward0>) tensor(5505772, device='cuda:0')
# 3979 2 tensor(5.7861, device='cuda:0', grad_fn=<DivBackward0>) tensor(5507818, device='cuda:0')
# 3980 2 tensor(5.7861, device='cuda:0', grad_fn=<DivBackward0>) tensor(5509864, device='cuda:0')
# 3981 2 tensor(5.7863, device='cuda:0', grad_fn=<DivBackward0>) tensor(5511601, device='cuda:0')
# 3982 2 tensor(5.7863, device='cuda:0', grad_fn=<DivBackward0>) tensor(5513338, device='cuda:0')
# 3983 2 tensor(5.7864, device='cuda:0', grad_fn=<DivBackward0>) tensor(5514866, device='cuda:0')
# 3984 2 tensor(5.7865, device='cuda:0', grad_fn=<DivBackward0>) tensor(5516394, device='cuda:0')
# 3985 2 tensor(5.7865, device='cuda:0', grad_fn=<DivBackward0>) tensor(5518124, device='cuda:0')
# 3986 2 tensor(5.7864, device='cuda:0', grad_fn=<DivBackward0>) tensor(5519854, device='cuda:0')
# 3987 2 tensor(5.7864, device='cuda:0', grad_fn=<DivBackward0>) tensor(5521445, device='cuda:0')
# 3988 2 tensor(5.7865, device='cuda:0', grad_fn=<DivBackward0>) tensor(5523036, device='cuda:0')
# 3989 2 tensor(5.7865, device='cuda:0', grad_fn=<DivBackward0>) tensor(5524524, device='cuda:0')
# 3990 2 tensor(5.7866, device='cuda:0', grad_fn=<DivBackward0>) tensor(5525454, device='cuda:0')
# 3991 2 tensor(5.7867, device='cuda:0', grad_fn=<DivBackward0>) tensor(5526133, device='cuda:0')
# 3992 2 tensor(5.7866, device='cuda:0', grad_fn=<DivBackward0>) tensor(5527370, device='cuda:0')
# 3993 2 tensor(5.7865, device='cuda:0', grad_fn=<DivBackward0>) tensor(5528618, device='cuda:0')
# 3994 2 tensor(5.7866, device='cuda:0', grad_fn=<DivBackward0>) tensor(5529866, device='cuda:0')
# 3995 2 tensor(5.7867, device='cuda:0', grad_fn=<DivBackward0>) tensor(5531912, device='cuda:0')
# 3996 2 tensor(5.7868, device='cuda:0', grad_fn=<DivBackward0>) tensor(5533547, device='cuda:0')
# 3997 2 tensor(5.7869, device='cuda:0', grad_fn=<DivBackward0>) tensor(5534637, device='cuda:0')
# 3998 2 tensor(5.7869, device='cuda:0', grad_fn=<DivBackward0>) tensor(5535406, device='cuda:0')
# 3999 2 tensor(5.7869, device='cuda:0', grad_fn=<DivBackward0>) tensor(5536720, device='cuda:0')
# (tensor(5.7869, device='cuda:0', grad_fn=<DivBackward0>), tensor(5538766, device='cuda:0'))

# %%
# Generations are still nonsense
test_model(simpleGPT2, text = "Mary is the greatest. Or is she?", steps = 100, sampling = top_k_sampling(10))
# Out:
# Starting prompt: Jonathan is a writer. He writes about political figures in Germany. What does he write about?
# <ipython-input-78-65651643be1d>:5: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   probs = t.nn.functional.softmax(logits)
# Current generation: Jonathan is a writer. He writes about political figures in Germany. What does he write about?�­ation����������­�ation���ation���­、��������­i u�­ation�i��し����i uiation�­��はation、�­��r��­い­­­������ation��ationation�������­����­­�ん�­
